# %% [raw]
# !wget https://github.com/rdfia/rdfia.github.io/raw/master/data/2-ab.zip && unzip -j 2-ab.zip > /dev/null
# !wget https://github.com/rdfia/rdfia.github.io/raw/master/code/2-ab/utils-data.py

# %%
# !mv utils-data.py utilsdata.py
import math
import torch
from torch.autograd import Variable
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from utilsdata import *

# %% [markdown]
# # Part 1 : Forward and backward passes "by hands"

# %%
def init_params(nx, nh, ny):
    """
    nx, nh, ny: integers
    out params: dictionnary
    """
    params = {}
    
    #####################
    ## Your code here  ##
    #####################
    # fill values for Wh, Wy, bh, by
    
    params["Wh"] = torch.randn(nh, nx)
    params["Wy"] = torch.randn(ny, nh)
    params["bh"] = torch.randn(nh)
    params["by"] = torch.randn(ny)
    
    ####################
    ##      END        #
    ####################
    return params

# %%
def forward(params, X):
    """
    params: dictionnary
    X: (n_batch, dimension)
    """
    bsize = X.size(0)
    nh = params['Wh'].size(0)
    ny = params['Wy'].size(0)
    outputs = {}

    #####################
    ## Your code here  ##
    #####################
    # fill values for X, htilde, h, ytilde, yhat
    
    outputs["X"] = X
    outputs["htilde"] = torch.mm(X, params["Wh"].T) + params["bh"]
    outputs["h"] = torch.tanh(outputs["htilde"])
    outputs["ytilde"] = torch.mm(outputs["h"], params["Wy"].T)  + params["by"]
    outputs["yhat"] = torch.softmax(outputs["ytilde"], dim=1)
    
    ####################
    ##      END        #
    ####################

    return outputs['yhat'], outputs

# %%
def loss_accuracy(Yhat, Y):

    bsize = Y.shape[0]

    #####################
    ## Your code here  ##
    #####################

    L = -torch.mean(torch.sum(Y * torch.log(Yhat), dim=1))
    _, idxY = torch.max(Y, dim=1)
    _, idxYhat = torch.max(Yhat, dim=1)
    acc = torch.sum(idxY == idxYhat) / bsize

    ####################
    ##      END        #
    ####################

    return L, acc

# %%
def backward(params, outputs, Y):
    bsize = Y.shape[0]
    grads = {}

    #####################
    ## Your code here  ##
    #####################
    # fill values for Wy, Wh, by, bh

    grads_yhat = (outputs["yhat"] - Y) / bsize
    grads["Wy"] = torch.mm(outputs["h"].T, grads_yhat)
    grads_h = torch.mm(grads_yhat, params["Wy"]) * (1 - outputs["h"]**2)
    grads["Wh"] = torch.mm(outputs["X"].T, grads_h)
    grads["by"] = torch.sum(grads_yhat, dim=0)
    grads["bh"] = torch.sum(grads_h, dim=0)
    
    ####################
    ##      END        #
    ####################
    return grads

# %%
def sgd(params, grads, eta):

    #####################
    ## Your code here  ##
    #####################
    # update the params values

    params["Wh"] -= eta * grads["Wh"].T
    params["Wy"] -= eta * grads["Wy"].T
    params["bh"] -= eta * grads["bh"]
    params["by"] -= eta * grads["by"]

    ####################
    ##      END        #
    ####################
    return params

# %% [markdown]
# ## Global learning procedure "by hands"

# %%
# init
data = CirclesData()
data.plot_data()
N = data.Xtrain.shape[0]
Nbatch = 10
nx = data.Xtrain.shape[1]
nh = 10
ny = data.Ytrain.shape[1]
eta = 0.03

params = init_params(nx, nh, ny)

curves = [[],[], [], []]

# epoch
for iteration in range(150):

    # permute
    perm = np.random.permutation(N)
    Xtrain = data.Xtrain[perm, :]
    Ytrain = data.Ytrain[perm, :]

    #####################
    ## Your code here  ##
    #####################
    # batches
    for j in range(N // Nbatch):

        indsBatch = range(j * Nbatch, (j+1) * Nbatch)
        X = Xtrain[indsBatch, :]
        Y = Ytrain[indsBatch, :]

        # write the optimization algorithm on the batch (X,Y)
        # using the functions: forward, loss_accuracy, backward, sgd
        yhat, outputs = forward(params, X)
        L, acc = loss_accuracy(yhat, Y)
        grads = backward(params, outputs, Y)
        params = sgd(params, grads, eta)


    ####################
    ##      END        #
    ####################


    Yhat_train, _ = forward(params, data.Xtrain)
    Yhat_test, _ = forward(params, data.Xtest)
    Ltrain, acctrain = loss_accuracy(Yhat_train, data.Ytrain)
    Ltest, acctest = loss_accuracy(Yhat_test, data.Ytest)
    Ygrid, _ = forward(params, data.Xgrid)  

    title = 'Iter {}: Acc train {:.1f}% ({:.2f}), acc test {:.1f}% ({:.2f})'.format(iteration, acctrain, Ltrain, acctest, Ltest)
    print(title)
    # data.plot_data_with_grid(Ygrid, title)

    curves[0].append(acctrain)
    curves[1].append(acctest)
    curves[2].append(Ltrain)
    curves[3].append(Ltest)

data.plot_data_with_grid(Ygrid, title)

fig = plt.figure()
plt.plot(curves[0], label="acc. train")
plt.plot(curves[1], label="acc. test")
plt.plot(curves[2], label="loss train")
plt.plot(curves[3], label="loss test")
plt.legend()
plt.show()
# Out:
# Iter 0: Acc train 0.4% (0.93), acc test 0.4% (0.95)
# Iter 1: Acc train 0.4% (0.84), acc test 0.5% (0.86)
# Iter 2: Acc train 0.6% (0.76), acc test 0.5% (0.79)
# Iter 3: Acc train 0.6% (0.71), acc test 0.6% (0.74)
# Iter 4: Acc train 0.7% (0.66), acc test 0.6% (0.70)
# Iter 5: Acc train 0.7% (0.63), acc test 0.6% (0.66)
# Iter 6: Acc train 0.7% (0.60), acc test 0.7% (0.63)
# Iter 7: Acc train 0.7% (0.57), acc test 0.7% (0.61)
# Iter 8: Acc train 0.7% (0.55), acc test 0.7% (0.59)
# Iter 9: Acc train 0.7% (0.53), acc test 0.7% (0.57)
# Iter 10: Acc train 0.7% (0.52), acc test 0.7% (0.55)
# Iter 11: Acc train 0.7% (0.51), acc test 0.7% (0.54)
# Iter 12: Acc train 0.7% (0.49), acc test 0.8% (0.53)
# Iter 13: Acc train 0.7% (0.48), acc test 0.8% (0.52)
# Iter 14: Acc train 0.8% (0.47), acc test 0.8% (0.51)
# Iter 15: Acc train 0.8% (0.46), acc test 0.8% (0.50)
# Iter 16: Acc train 0.8% (0.45), acc test 0.8% (0.49)
# Iter 17: Acc train 0.8% (0.45), acc test 0.8% (0.48)
# Iter 18: Acc train 0.8% (0.44), acc test 0.8% (0.48)
# Iter 19: Acc train 0.8% (0.43), acc test 0.8% (0.47)
# Iter 20: Acc train 0.8% (0.43), acc test 0.8% (0.46)
# Iter 21: Acc train 0.8% (0.42), acc test 0.8% (0.45)
# Iter 22: Acc train 0.8% (0.41), acc test 0.8% (0.45)
# Iter 23: Acc train 0.8% (0.41), acc test 0.8% (0.44)
# Iter 24: Acc train 0.8% (0.40), acc test 0.8% (0.44)
# Iter 25: Acc train 0.8% (0.40), acc test 0.8% (0.43)
# Iter 26: Acc train 0.8% (0.39), acc test 0.8% (0.42)
# Iter 27: Acc train 0.8% (0.39), acc test 0.9% (0.42)
# Iter 28: Acc train 0.8% (0.38), acc test 0.9% (0.42)
# Iter 29: Acc train 0.8% (0.38), acc test 0.9% (0.41)
# Iter 30: Acc train 0.8% (0.37), acc test 0.9% (0.40)
# Iter 31: Acc train 0.8% (0.37), acc test 0.9% (0.40)
# Iter 32: Acc train 0.8% (0.36), acc test 0.9% (0.39)
# Iter 33: Acc train 0.9% (0.36), acc test 0.9% (0.39)
# Iter 34: Acc train 0.9% (0.35), acc test 0.9% (0.38)
# Iter 35: Acc train 0.9% (0.35), acc test 0.9% (0.38)
# Iter 36: Acc train 0.9% (0.34), acc test 0.9% (0.38)
# Iter 37: Acc train 0.9% (0.34), acc test 0.9% (0.37)
# Iter 38: Acc train 0.9% (0.34), acc test 0.9% (0.37)
# Iter 39: Acc train 0.9% (0.33), acc test 0.9% (0.36)
# Iter 40: Acc train 0.9% (0.33), acc test 0.9% (0.36)
# Iter 41: Acc train 0.9% (0.32), acc test 0.9% (0.35)
# Iter 42: Acc train 0.9% (0.32), acc test 0.9% (0.35)
# Iter 43: Acc train 0.9% (0.32), acc test 0.9% (0.34)
# Iter 44: Acc train 0.9% (0.31), acc test 0.9% (0.34)
# Iter 45: Acc train 0.9% (0.31), acc test 0.9% (0.33)
# Iter 46: Acc train 0.9% (0.30), acc test 0.9% (0.33)
# Iter 47: Acc train 0.9% (0.30), acc test 0.9% (0.33)
# Iter 48: Acc train 0.9% (0.30), acc test 0.9% (0.32)
# Iter 49: Acc train 0.9% (0.29), acc test 0.9% (0.32)
# Iter 50: Acc train 0.9% (0.29), acc test 0.9% (0.31)
# Iter 51: Acc train 0.9% (0.29), acc test 0.9% (0.31)
# Iter 52: Acc train 0.9% (0.28), acc test 0.9% (0.31)
# Iter 53: Acc train 0.9% (0.28), acc test 0.9% (0.30)
# Iter 54: Acc train 0.9% (0.28), acc test 0.9% (0.30)
# Iter 55: Acc train 0.9% (0.27), acc test 0.9% (0.30)
# Iter 56: Acc train 0.9% (0.27), acc test 0.9% (0.29)
# Iter 57: Acc train 0.9% (0.27), acc test 0.9% (0.29)
# Iter 58: Acc train 0.9% (0.27), acc test 0.9% (0.29)
# Iter 59: Acc train 0.9% (0.26), acc test 0.9% (0.28)
# Iter 60: Acc train 0.9% (0.26), acc test 0.9% (0.28)
# Iter 61: Acc train 0.9% (0.26), acc test 0.9% (0.28)
# Iter 62: Acc train 0.9% (0.25), acc test 0.9% (0.27)
# Iter 63: Acc train 0.9% (0.25), acc test 0.9% (0.27)
# Iter 64: Acc train 0.9% (0.25), acc test 0.9% (0.27)
# Iter 65: Acc train 0.9% (0.25), acc test 0.9% (0.26)
# Iter 66: Acc train 0.9% (0.24), acc test 0.9% (0.26)
# Iter 67: Acc train 0.9% (0.24), acc test 0.9% (0.26)
# Iter 68: Acc train 0.9% (0.24), acc test 0.9% (0.26)
# Iter 69: Acc train 0.9% (0.24), acc test 0.9% (0.25)
# Iter 70: Acc train 0.9% (0.24), acc test 0.9% (0.25)
# Iter 71: Acc train 0.9% (0.23), acc test 0.9% (0.25)
# Iter 72: Acc train 0.9% (0.23), acc test 0.9% (0.25)
# Iter 73: Acc train 0.9% (0.23), acc test 0.9% (0.24)
# Iter 74: Acc train 0.9% (0.23), acc test 0.9% (0.24)
# Iter 75: Acc train 0.9% (0.23), acc test 0.9% (0.24)
# Iter 76: Acc train 0.9% (0.22), acc test 0.9% (0.24)
# Iter 77: Acc train 0.9% (0.22), acc test 0.9% (0.24)
# Iter 78: Acc train 0.9% (0.22), acc test 0.9% (0.23)
# Iter 79: Acc train 0.9% (0.22), acc test 0.9% (0.23)
# Iter 80: Acc train 0.9% (0.22), acc test 0.9% (0.23)
# Iter 81: Acc train 0.9% (0.22), acc test 0.9% (0.23)
# Iter 82: Acc train 0.9% (0.21), acc test 0.9% (0.23)
# Iter 83: Acc train 0.9% (0.21), acc test 0.9% (0.22)
# Iter 84: Acc train 0.9% (0.21), acc test 0.9% (0.22)
# Iter 85: Acc train 0.9% (0.21), acc test 0.9% (0.22)
# Iter 86: Acc train 0.9% (0.21), acc test 0.9% (0.22)
# Iter 87: Acc train 0.9% (0.21), acc test 0.9% (0.22)
# Iter 88: Acc train 0.9% (0.21), acc test 0.9% (0.22)
# Iter 89: Acc train 0.9% (0.20), acc test 0.9% (0.21)
# Iter 90: Acc train 0.9% (0.20), acc test 0.9% (0.21)
# Iter 91: Acc train 0.9% (0.20), acc test 0.9% (0.21)
# Iter 92: Acc train 0.9% (0.20), acc test 0.9% (0.21)
# Iter 93: Acc train 0.9% (0.20), acc test 0.9% (0.21)
# Iter 94: Acc train 0.9% (0.20), acc test 0.9% (0.21)
# Iter 95: Acc train 0.9% (0.20), acc test 0.9% (0.21)
# Iter 96: Acc train 1.0% (0.20), acc test 0.9% (0.21)
# Iter 97: Acc train 0.9% (0.19), acc test 0.9% (0.20)
# Iter 98: Acc train 0.9% (0.19), acc test 0.9% (0.20)
# Iter 99: Acc train 0.9% (0.19), acc test 0.9% (0.20)
# Iter 100: Acc train 0.9% (0.19), acc test 0.9% (0.20)
# Iter 101: Acc train 0.9% (0.19), acc test 0.9% (0.20)
# Iter 102: Acc train 0.9% (0.19), acc test 0.9% (0.20)
# Iter 103: Acc train 0.9% (0.19), acc test 0.9% (0.20)
# Iter 104: Acc train 0.9% (0.19), acc test 0.9% (0.20)
# Iter 105: Acc train 0.9% (0.19), acc test 0.9% (0.20)
# Iter 106: Acc train 0.9% (0.19), acc test 0.9% (0.20)
# Iter 107: Acc train 0.9% (0.19), acc test 0.9% (0.19)
# Iter 108: Acc train 0.9% (0.18), acc test 0.9% (0.19)
# Iter 109: Acc train 0.9% (0.18), acc test 0.9% (0.19)
# Iter 110: Acc train 0.9% (0.18), acc test 0.9% (0.19)
# Iter 111: Acc train 0.9% (0.18), acc test 0.9% (0.19)
# Iter 112: Acc train 0.9% (0.18), acc test 0.9% (0.19)
# Iter 113: Acc train 0.9% (0.18), acc test 0.9% (0.19)
# Iter 114: Acc train 0.9% (0.18), acc test 0.9% (0.19)
# Iter 115: Acc train 0.9% (0.18), acc test 0.9% (0.19)
# Iter 116: Acc train 0.9% (0.18), acc test 0.9% (0.19)
# Iter 117: Acc train 0.9% (0.18), acc test 0.9% (0.19)
# Iter 118: Acc train 0.9% (0.18), acc test 0.9% (0.19)
# Iter 119: Acc train 0.9% (0.18), acc test 0.9% (0.18)
# Iter 120: Acc train 0.9% (0.18), acc test 0.9% (0.18)
# Iter 121: Acc train 0.9% (0.18), acc test 0.9% (0.18)
# Iter 122: Acc train 0.9% (0.18), acc test 0.9% (0.18)
# Iter 123: Acc train 0.9% (0.17), acc test 0.9% (0.18)
# Iter 124: Acc train 0.9% (0.17), acc test 0.9% (0.18)
# Iter 125: Acc train 0.9% (0.17), acc test 0.9% (0.18)
# Iter 126: Acc train 0.9% (0.17), acc test 0.9% (0.18)
# Iter 127: Acc train 0.9% (0.17), acc test 0.9% (0.18)
# Iter 128: Acc train 0.9% (0.17), acc test 0.9% (0.18)
# Iter 129: Acc train 0.9% (0.17), acc test 0.9% (0.18)
# Iter 130: Acc train 0.9% (0.17), acc test 0.9% (0.18)
# Iter 131: Acc train 0.9% (0.17), acc test 0.9% (0.18)
# Iter 132: Acc train 0.9% (0.17), acc test 0.9% (0.18)
# Iter 133: Acc train 0.9% (0.17), acc test 0.9% (0.18)
# Iter 134: Acc train 0.9% (0.17), acc test 0.9% (0.18)
# Iter 135: Acc train 0.9% (0.17), acc test 0.9% (0.18)
# Iter 136: Acc train 0.9% (0.17), acc test 0.9% (0.17)
# Iter 137: Acc train 0.9% (0.17), acc test 0.9% (0.17)
# Iter 138: Acc train 0.9% (0.17), acc test 0.9% (0.17)
# Iter 139: Acc train 0.9% (0.17), acc test 0.9% (0.17)
# Iter 140: Acc train 0.9% (0.17), acc test 0.9% (0.17)
# Iter 141: Acc train 0.9% (0.17), acc test 0.9% (0.17)
# Iter 142: Acc train 0.9% (0.17), acc test 0.9% (0.17)
# Iter 143: Acc train 0.9% (0.17), acc test 0.9% (0.17)
# Iter 144: Acc train 0.9% (0.17), acc test 0.9% (0.17)
# Iter 145: Acc train 0.9% (0.16), acc test 0.9% (0.17)
# Iter 146: Acc train 0.9% (0.16), acc test 0.9% (0.17)
# Iter 147: Acc train 0.9% (0.16), acc test 0.9% (0.17)
# Iter 148: Acc train 0.9% (0.16), acc test 0.9% (0.17)
# Iter 149: Acc train 0.9% (0.16), acc test 0.9% (0.17)

# %% [markdown]
# # Part 2 : Simplification of the backward pass with `torch.autograd`

# %%
def init_params(nx, nh, ny):
    """
    nx, nh, ny: integers
    out params: dictionnary
    """
    params = {}
    
    #####################
    ## Your code here  ##
    #####################
    # fill values for Wh, Wy, bh, by
    # activaye autograd on the network weights
    
    params["Wh"] = torch.randn(nh, nx, requires_grad=True)
    params["Wy"] = torch.randn(ny, nh, requires_grad=True)
    params["bh"] = torch.randn(nh, requires_grad=True)
    params["by"] = torch.randn(ny, requires_grad=True)
    
    ####################
    ##      END        #
    ####################
    return params

# %% [markdown]
# The function `forward` remains unchanged from previous part.
#
# The function `backward` is no longer used because of "autograd".

# %%
def sgd(params, eta):

    #####################
    ## Your code here  ##
    #####################
    # update the network weights
    # warning: use torch.no_grad()
    # and reset to zero the gradient accumulators
    with torch.no_grad():
      params["Wh"] -= eta * params["Wh"].grad
      params["Wy"] -= eta * params["Wy"].grad
      params["bh"] -= eta * params["bh"].grad
      params["by"] -= eta * params["by"].grad

    params["Wh"].grad.zero_()
    params["Wy"].grad.zero_()
    params["bh"].grad.zero_()
    params["by"].grad.zero_()

    ####################
    ##      END        #
    ####################
    return params

# %% [markdown]
# ## Global learning procedure with autograd

# %%
# init
data = CirclesData()
data.plot_data()
N = data.Xtrain.shape[0]
Nbatch = 10
nx = data.Xtrain.shape[1]
nh = 10
ny = data.Ytrain.shape[1]
eta = 0.03

params = init_params(nx, nh, ny)

curves = [[],[], [], []]

# epoch
for iteration in range(150):

    # permute
    perm = np.random.permutation(N)
    Xtrain = data.Xtrain[perm, :]
    Ytrain = data.Ytrain[perm, :]

    #####################
    ## Your code here  ##
    #####################
    # batches
    for j in range(N // Nbatch):

        indsBatch = range(j * Nbatch, (j+1) * Nbatch)
        X = Xtrain[indsBatch, :]
        Y = Ytrain[indsBatch, :]
  
        # write the optimization algorithm on the batch (X,Y)
        # using the functions: forward, loss_accuracy, sgd
        # and the backward function with autograd
        yhat, outputs = forward(params, X)
        L, acc = loss_accuracy(yhat, Y)
        L.backward()
        params = sgd(params, eta)

    ####################
    ##      END        #
    ####################


    Yhat_train, _ = forward(params, data.Xtrain)
    Yhat_test, _ = forward(params, data.Xtest)
    Ltrain, acctrain = loss_accuracy(Yhat_train, data.Ytrain)
    Ltest, acctest = loss_accuracy(Yhat_test, data.Ytest)
    Ygrid, _ = forward(params, data.Xgrid)  

    title = 'Iter {}: Acc train {:.1f}% ({:.2f}), acc test {:.1f}% ({:.2f})'.format(iteration, acctrain, Ltrain, acctest, Ltest)
    print(title)
    # detach() is used to remove the predictions from the computational graph in autograd

    curves[0].append(acctrain)
    curves[1].append(acctest)
    curves[2].append(Ltrain.detach().numpy())
    curves[3].append(Ltest.detach().numpy())

data.plot_data_with_grid(Ygrid.detach(), title)
fig = plt.figure()
plt.plot(curves[0], label="acc. train")
plt.plot(curves[1], label="acc. test")
plt.plot(curves[2], label="loss train")
plt.plot(curves[3], label="loss test")
plt.legend()
plt.show()
# Out:
# Iter 0: Acc train 0.8% (0.56), acc test 0.8% (0.54)
# Iter 1: Acc train 0.8% (0.53), acc test 0.9% (0.52)
# Iter 2: Acc train 0.9% (0.52), acc test 0.9% (0.51)
# Iter 3: Acc train 0.9% (0.50), acc test 0.9% (0.49)
# Iter 4: Acc train 0.9% (0.49), acc test 1.0% (0.48)
# Iter 5: Acc train 0.9% (0.47), acc test 0.9% (0.46)
# Iter 6: Acc train 0.9% (0.46), acc test 0.9% (0.45)
# Iter 7: Acc train 0.9% (0.45), acc test 0.9% (0.44)
# Iter 8: Acc train 0.9% (0.44), acc test 0.9% (0.43)
# Iter 9: Acc train 0.9% (0.43), acc test 0.9% (0.42)
# Iter 10: Acc train 0.9% (0.42), acc test 1.0% (0.41)
# Iter 11: Acc train 0.9% (0.41), acc test 1.0% (0.40)
# Iter 12: Acc train 0.9% (0.40), acc test 1.0% (0.39)
# Iter 13: Acc train 0.9% (0.39), acc test 1.0% (0.39)
# Iter 14: Acc train 0.9% (0.38), acc test 1.0% (0.38)
# Iter 15: Acc train 0.9% (0.37), acc test 1.0% (0.37)
# Iter 16: Acc train 0.9% (0.37), acc test 1.0% (0.36)
# Iter 17: Acc train 0.9% (0.36), acc test 1.0% (0.36)
# Iter 18: Acc train 0.9% (0.35), acc test 1.0% (0.35)
# Iter 19: Acc train 0.9% (0.35), acc test 1.0% (0.34)
# Iter 20: Acc train 0.9% (0.34), acc test 1.0% (0.34)
# Iter 21: Acc train 0.9% (0.33), acc test 1.0% (0.33)
# Iter 22: Acc train 0.9% (0.33), acc test 1.0% (0.33)
# Iter 23: Acc train 0.9% (0.32), acc test 1.0% (0.32)
# Iter 24: Acc train 0.9% (0.32), acc test 1.0% (0.32)
# Iter 25: Acc train 0.9% (0.31), acc test 1.0% (0.31)
# Iter 26: Acc train 0.9% (0.31), acc test 1.0% (0.30)
# Iter 27: Acc train 0.9% (0.30), acc test 1.0% (0.30)
# Iter 28: Acc train 0.9% (0.30), acc test 1.0% (0.30)
# Iter 29: Acc train 0.9% (0.29), acc test 1.0% (0.29)
# Iter 30: Acc train 0.9% (0.29), acc test 1.0% (0.29)
# Iter 31: Acc train 0.9% (0.29), acc test 1.0% (0.28)
# Iter 32: Acc train 0.9% (0.28), acc test 1.0% (0.28)
# Iter 33: Acc train 0.9% (0.28), acc test 1.0% (0.28)
# Iter 34: Acc train 0.9% (0.27), acc test 1.0% (0.27)
# Iter 35: Acc train 0.9% (0.27), acc test 1.0% (0.27)
# Iter 36: Acc train 0.9% (0.27), acc test 1.0% (0.27)
# Iter 37: Acc train 0.9% (0.26), acc test 1.0% (0.26)
# Iter 38: Acc train 0.9% (0.26), acc test 1.0% (0.26)
# Iter 39: Acc train 0.9% (0.26), acc test 1.0% (0.26)
# Iter 40: Acc train 0.9% (0.25), acc test 1.0% (0.25)
# Iter 41: Acc train 0.9% (0.25), acc test 1.0% (0.25)
# Iter 42: Acc train 0.9% (0.25), acc test 1.0% (0.25)
# Iter 43: Acc train 0.9% (0.25), acc test 1.0% (0.25)
# Iter 44: Acc train 0.9% (0.24), acc test 0.9% (0.25)
# Iter 45: Acc train 1.0% (0.24), acc test 0.9% (0.24)
# Iter 46: Acc train 1.0% (0.24), acc test 0.9% (0.24)
# Iter 47: Acc train 0.9% (0.24), acc test 0.9% (0.24)
# Iter 48: Acc train 0.9% (0.23), acc test 0.9% (0.24)
# Iter 49: Acc train 1.0% (0.23), acc test 0.9% (0.24)
# Iter 50: Acc train 0.9% (0.23), acc test 0.9% (0.23)
# Iter 51: Acc train 0.9% (0.23), acc test 0.9% (0.23)
# Iter 52: Acc train 0.9% (0.23), acc test 0.9% (0.23)
# Iter 53: Acc train 0.9% (0.22), acc test 0.9% (0.23)
# Iter 54: Acc train 0.9% (0.22), acc test 0.9% (0.22)
# Iter 55: Acc train 0.9% (0.22), acc test 0.9% (0.22)
# Iter 56: Acc train 1.0% (0.22), acc test 0.9% (0.22)
# Iter 57: Acc train 0.9% (0.22), acc test 0.9% (0.22)
# Iter 58: Acc train 1.0% (0.21), acc test 0.9% (0.22)
# Iter 59: Acc train 0.9% (0.21), acc test 0.9% (0.22)
# Iter 60: Acc train 0.9% (0.21), acc test 0.9% (0.21)
# Iter 61: Acc train 0.9% (0.21), acc test 0.9% (0.21)
# Iter 62: Acc train 0.9% (0.21), acc test 0.9% (0.21)
# Iter 63: Acc train 0.9% (0.21), acc test 0.9% (0.21)
# Iter 64: Acc train 0.9% (0.20), acc test 0.9% (0.21)
# Iter 65: Acc train 0.9% (0.20), acc test 0.9% (0.21)
# Iter 66: Acc train 0.9% (0.20), acc test 0.9% (0.21)
# Iter 67: Acc train 0.9% (0.20), acc test 0.9% (0.21)
# Iter 68: Acc train 0.9% (0.20), acc test 0.9% (0.21)
# Iter 69: Acc train 0.9% (0.20), acc test 0.9% (0.20)
# Iter 70: Acc train 0.9% (0.20), acc test 0.9% (0.20)
# Iter 71: Acc train 1.0% (0.19), acc test 0.9% (0.20)
# Iter 72: Acc train 1.0% (0.19), acc test 0.9% (0.20)
# Iter 73: Acc train 1.0% (0.19), acc test 0.9% (0.20)
# Iter 74: Acc train 0.9% (0.19), acc test 0.9% (0.20)
# Iter 75: Acc train 1.0% (0.19), acc test 0.9% (0.20)
# Iter 76: Acc train 1.0% (0.19), acc test 0.9% (0.20)
# Iter 77: Acc train 1.0% (0.19), acc test 0.9% (0.20)
# Iter 78: Acc train 1.0% (0.19), acc test 0.9% (0.20)
# Iter 79: Acc train 1.0% (0.19), acc test 0.9% (0.19)
# Iter 80: Acc train 0.9% (0.18), acc test 0.9% (0.19)
# Iter 81: Acc train 0.9% (0.18), acc test 0.9% (0.19)
# Iter 82: Acc train 0.9% (0.18), acc test 0.9% (0.19)
# Iter 83: Acc train 0.9% (0.18), acc test 0.9% (0.19)
# Iter 84: Acc train 1.0% (0.18), acc test 0.9% (0.19)
# Iter 85: Acc train 1.0% (0.18), acc test 0.9% (0.19)
# Iter 86: Acc train 1.0% (0.18), acc test 0.9% (0.19)
# Iter 87: Acc train 1.0% (0.18), acc test 0.9% (0.19)
# Iter 88: Acc train 1.0% (0.18), acc test 0.9% (0.19)
# Iter 89: Acc train 1.0% (0.18), acc test 0.9% (0.18)
# Iter 90: Acc train 1.0% (0.18), acc test 0.9% (0.18)
# Iter 91: Acc train 1.0% (0.17), acc test 0.9% (0.18)
# Iter 92: Acc train 1.0% (0.17), acc test 0.9% (0.18)
# Iter 93: Acc train 1.0% (0.17), acc test 0.9% (0.18)
# Iter 94: Acc train 1.0% (0.17), acc test 0.9% (0.18)
# Iter 95: Acc train 1.0% (0.17), acc test 0.9% (0.18)
# Iter 96: Acc train 1.0% (0.17), acc test 0.9% (0.18)
# Iter 97: Acc train 1.0% (0.17), acc test 0.9% (0.18)
# Iter 98: Acc train 1.0% (0.17), acc test 0.9% (0.18)
# Iter 99: Acc train 1.0% (0.17), acc test 0.9% (0.18)
# Iter 100: Acc train 1.0% (0.17), acc test 0.9% (0.18)
# Iter 101: Acc train 1.0% (0.17), acc test 0.9% (0.18)
# Iter 102: Acc train 1.0% (0.17), acc test 0.9% (0.18)
# Iter 103: Acc train 1.0% (0.17), acc test 0.9% (0.18)
# Iter 104: Acc train 1.0% (0.17), acc test 0.9% (0.18)
# Iter 105: Acc train 1.0% (0.16), acc test 0.9% (0.18)
# Iter 106: Acc train 1.0% (0.16), acc test 0.9% (0.18)
# Iter 107: Acc train 1.0% (0.16), acc test 0.9% (0.18)
# Iter 108: Acc train 1.0% (0.16), acc test 0.9% (0.18)
# Iter 109: Acc train 1.0% (0.16), acc test 0.9% (0.18)
# Iter 110: Acc train 1.0% (0.16), acc test 0.9% (0.18)
# Iter 111: Acc train 1.0% (0.16), acc test 0.9% (0.17)
# Iter 112: Acc train 1.0% (0.16), acc test 0.9% (0.17)
# Iter 113: Acc train 1.0% (0.16), acc test 0.9% (0.17)
# Iter 114: Acc train 1.0% (0.16), acc test 0.9% (0.17)
# Iter 115: Acc train 1.0% (0.16), acc test 0.9% (0.17)
# Iter 116: Acc train 1.0% (0.16), acc test 0.9% (0.17)
# Iter 117: Acc train 1.0% (0.16), acc test 0.9% (0.17)
# Iter 118: Acc train 1.0% (0.16), acc test 0.9% (0.17)
# Iter 119: Acc train 1.0% (0.16), acc test 0.9% (0.17)
# Iter 120: Acc train 1.0% (0.16), acc test 0.9% (0.17)
# Iter 121: Acc train 1.0% (0.16), acc test 0.9% (0.17)
# Iter 122: Acc train 1.0% (0.16), acc test 0.9% (0.17)
# Iter 123: Acc train 1.0% (0.15), acc test 0.9% (0.17)
# Iter 124: Acc train 1.0% (0.15), acc test 0.9% (0.17)
# Iter 125: Acc train 1.0% (0.15), acc test 0.9% (0.17)
# Iter 126: Acc train 1.0% (0.15), acc test 0.9% (0.17)
# Iter 127: Acc train 1.0% (0.15), acc test 0.9% (0.17)
# Iter 128: Acc train 1.0% (0.15), acc test 0.9% (0.17)
# Iter 129: Acc train 1.0% (0.15), acc test 0.9% (0.17)
# Iter 130: Acc train 1.0% (0.15), acc test 0.9% (0.17)
# Iter 131: Acc train 1.0% (0.15), acc test 0.9% (0.17)
# Iter 132: Acc train 1.0% (0.15), acc test 0.9% (0.17)
# Iter 133: Acc train 1.0% (0.15), acc test 0.9% (0.17)
# Iter 134: Acc train 1.0% (0.15), acc test 0.9% (0.17)
# Iter 135: Acc train 1.0% (0.15), acc test 0.9% (0.17)
# Iter 136: Acc train 1.0% (0.15), acc test 0.9% (0.17)
# Iter 137: Acc train 1.0% (0.15), acc test 0.9% (0.17)
# Iter 138: Acc train 1.0% (0.15), acc test 0.9% (0.17)
# Iter 139: Acc train 1.0% (0.15), acc test 0.9% (0.17)
# Iter 140: Acc train 1.0% (0.15), acc test 0.9% (0.17)
# Iter 141: Acc train 1.0% (0.15), acc test 0.9% (0.17)
# Iter 142: Acc train 1.0% (0.15), acc test 0.9% (0.17)
# Iter 143: Acc train 1.0% (0.15), acc test 0.9% (0.16)
# Iter 144: Acc train 1.0% (0.15), acc test 0.9% (0.16)
# Iter 145: Acc train 1.0% (0.15), acc test 0.9% (0.16)
# Iter 146: Acc train 1.0% (0.15), acc test 0.9% (0.16)
# Iter 147: Acc train 1.0% (0.14), acc test 0.9% (0.16)
# Iter 148: Acc train 1.0% (0.14), acc test 0.9% (0.16)
# Iter 149: Acc train 1.0% (0.14), acc test 0.9% (0.16)

# %% [markdown]
# # Part 3 : Simplification of the forward pass with `torch.nn`

# %% [markdown]
# `init_params` and `forward` are replaced by the `init_model` function which defines the network architecture and the loss.

# %%
def init_model(nx, nh, ny):

    #####################
    ## Your code here  ##
    #####################

    model = torch.nn.Sequential(
        torch.nn.Linear(nx,nh),
        torch.nn.Tanh(),
        torch.nn.Linear(nh,ny),
        torch.nn.Softmax())
    loss = torch.nn.MSELoss()

    ####################
    ##      END        #
    ####################

    return model, loss

# %%
def loss_accuracy(loss, Yhat, Y):

    #####################
    ## Your code here  ##
    #####################
    # call the loss function

    bsize = Yhat.shape[0]
    _, idxY = torch.max(Y, dim=1)
    _, idxYhat = torch.max(Yhat, dim=1)
    acc = torch.sum(idxY == idxYhat) / bsize
    L = loss(Yhat,Y)

    ####################
    ##      END        #
    ####################

    return L, acc

# %%
def sgd(model, eta):

    #####################
    ## Your code here  ##
    #####################
    # update the network weights
    # warning: use torch.no_grad()
    # and reset to zero the gradient accumulators

    with torch.no_grad():
        for param in model.parameters():
            param -= eta*param.grad
        model.zero_grad()

    ####################
    ##      END        #
    ####################
    return model

# %% [markdown]
# ## Global learning procedure with autograd and `torch.nn`

# %%
# init
data = CirclesData()
data.plot_data()
N = data.Xtrain.shape[0]
Nbatch = 10
nx = data.Xtrain.shape[1]
nh = 10
ny = data.Ytrain.shape[1]
eta = 0.03

model, loss = init_model(nx, nh, ny)

curves = [[],[], [], []]

# epoch
for iteration in range(150):

    # permute
    perm = np.random.permutation(N)
    Xtrain = data.Xtrain[perm, :]
    Ytrain = data.Ytrain[perm, :]

    #####################
    ## Your code here  ##
    #####################
    # batches
    for j in range(N // Nbatch):

        indsBatch = range(j * Nbatch, (j+1) * Nbatch)
        X = Xtrain[indsBatch, :]
        Y = Ytrain[indsBatch, :]

        # write the optimization algorithm on the batch (X,Y)
        # using the functions: loss_accuracy, sgd
        # the forward with the predict method from the model
        # and the backward function with autograd
        Yhat = model(X)
        L, acc = loss_accuracy(loss, Yhat, Y)
        L.backward()
        model = sgd(model, eta)

    ####################
    ##      END        #
    ####################


    Yhat_train = model(data.Xtrain)
    Yhat_test = model(data.Xtest)
    Ltrain, acctrain = loss_accuracy(loss, Yhat_train, data.Ytrain)
    Ltest, acctest = loss_accuracy(loss, Yhat_test, data.Ytest)
    Ygrid = model(data.Xgrid)  

    title = 'Iter {}: Acc train {:.1f}% ({:.2f}), acc test {:.1f}% ({:.2f})'.format(iteration, acctrain, Ltrain, acctest, Ltest)
    print(title) 

    curves[0].append(acctrain)
    curves[1].append(acctest)
    curves[2].append(Ltrain.detach().numpy())
    curves[3].append(Ltest.detach().numpy())

data.plot_data_with_grid(torch.nn.Softmax(dim=1)(Ygrid.detach()), title)
fig = plt.figure()
plt.plot(curves[0], label="acc. train")
plt.plot(curves[1], label="acc. test")
plt.plot(curves[2], label="loss train")
plt.plot(curves[3], label="loss test")
plt.legend()
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/container.py:141: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Iter 0: Acc train 0.4% (0.26), acc test 0.4% (0.26)
# Iter 1: Acc train 0.4% (0.25), acc test 0.4% (0.25)
# Iter 2: Acc train 0.4% (0.25), acc test 0.4% (0.25)
# Iter 3: Acc train 0.4% (0.25), acc test 0.5% (0.25)
# Iter 4: Acc train 0.5% (0.25), acc test 0.5% (0.25)
# Iter 5: Acc train 0.5% (0.25), acc test 0.6% (0.25)
# Iter 6: Acc train 0.6% (0.25), acc test 0.6% (0.25)
# Iter 7: Acc train 0.6% (0.25), acc test 0.6% (0.25)
# Iter 8: Acc train 0.6% (0.25), acc test 0.6% (0.25)
# Iter 9: Acc train 0.6% (0.25), acc test 0.6% (0.25)
# Iter 10: Acc train 0.6% (0.25), acc test 0.6% (0.25)
# Iter 11: Acc train 0.7% (0.25), acc test 0.7% (0.25)
# Iter 12: Acc train 0.7% (0.25), acc test 0.7% (0.25)
# Iter 13: Acc train 0.7% (0.25), acc test 0.7% (0.25)
# Iter 14: Acc train 0.7% (0.25), acc test 0.7% (0.25)
# Iter 15: Acc train 0.7% (0.25), acc test 0.7% (0.25)
# Iter 16: Acc train 0.7% (0.25), acc test 0.7% (0.25)
# Iter 17: Acc train 0.7% (0.25), acc test 0.7% (0.25)
# Iter 18: Acc train 0.7% (0.24), acc test 0.7% (0.25)
# Iter 19: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 20: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 21: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 22: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 23: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 24: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 25: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 26: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 27: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 28: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 29: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 30: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 31: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 32: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 33: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 34: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 35: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 36: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 37: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 38: Acc train 0.7% (0.24), acc test 0.8% (0.24)
# Iter 39: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 40: Acc train 0.7% (0.24), acc test 0.8% (0.24)
# Iter 41: Acc train 0.7% (0.24), acc test 0.8% (0.24)
# Iter 42: Acc train 0.7% (0.24), acc test 0.8% (0.24)
# Iter 43: Acc train 0.7% (0.24), acc test 0.8% (0.24)
# Iter 44: Acc train 0.7% (0.24), acc test 0.8% (0.24)
# Iter 45: Acc train 0.7% (0.24), acc test 0.8% (0.24)
# Iter 46: Acc train 0.7% (0.24), acc test 0.8% (0.24)
# Iter 47: Acc train 0.7% (0.24), acc test 0.8% (0.24)
# Iter 48: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 49: Acc train 0.8% (0.24), acc test 0.8% (0.24)
# Iter 50: Acc train 0.8% (0.23), acc test 0.8% (0.23)
# Iter 51: Acc train 0.8% (0.23), acc test 0.8% (0.23)
# Iter 52: Acc train 0.8% (0.23), acc test 0.8% (0.23)
# Iter 53: Acc train 0.8% (0.23), acc test 0.8% (0.23)
# Iter 54: Acc train 0.8% (0.23), acc test 0.8% (0.23)
# Iter 55: Acc train 0.8% (0.23), acc test 0.8% (0.23)
# Iter 56: Acc train 0.8% (0.23), acc test 0.8% (0.23)
# Iter 57: Acc train 0.8% (0.23), acc test 0.8% (0.23)
# Iter 58: Acc train 0.8% (0.23), acc test 0.8% (0.23)
# Iter 59: Acc train 0.8% (0.23), acc test 0.8% (0.23)
# Iter 60: Acc train 0.8% (0.23), acc test 0.8% (0.23)
# Iter 61: Acc train 0.8% (0.23), acc test 0.8% (0.23)
# Iter 62: Acc train 0.8% (0.23), acc test 0.8% (0.23)
# Iter 63: Acc train 0.8% (0.23), acc test 0.8% (0.23)
# Iter 64: Acc train 0.8% (0.23), acc test 0.8% (0.23)
# Iter 65: Acc train 0.8% (0.23), acc test 0.8% (0.23)
# Iter 66: Acc train 0.8% (0.23), acc test 0.8% (0.23)
# Iter 67: Acc train 0.8% (0.23), acc test 0.8% (0.23)
# Iter 68: Acc train 0.8% (0.23), acc test 0.8% (0.23)
# Iter 69: Acc train 0.8% (0.23), acc test 0.8% (0.23)
# Iter 70: Acc train 0.8% (0.23), acc test 0.8% (0.23)
# Iter 71: Acc train 0.8% (0.22), acc test 0.8% (0.22)
# Iter 72: Acc train 0.8% (0.22), acc test 0.8% (0.22)
# Iter 73: Acc train 0.8% (0.22), acc test 0.8% (0.22)
# Iter 74: Acc train 0.8% (0.22), acc test 0.8% (0.22)
# Iter 75: Acc train 0.8% (0.22), acc test 0.8% (0.22)
# Iter 76: Acc train 0.8% (0.22), acc test 0.8% (0.22)
# Iter 77: Acc train 0.8% (0.22), acc test 0.8% (0.22)
# Iter 78: Acc train 0.8% (0.22), acc test 0.8% (0.22)
# Iter 79: Acc train 0.8% (0.22), acc test 0.8% (0.22)
# Iter 80: Acc train 0.8% (0.22), acc test 0.8% (0.22)
# Iter 81: Acc train 0.8% (0.22), acc test 0.8% (0.22)
# Iter 82: Acc train 0.8% (0.22), acc test 0.8% (0.22)
# Iter 83: Acc train 0.8% (0.22), acc test 0.8% (0.22)
# Iter 84: Acc train 0.8% (0.22), acc test 0.8% (0.22)
# Iter 85: Acc train 0.8% (0.22), acc test 0.8% (0.22)
# Iter 86: Acc train 0.8% (0.21), acc test 0.8% (0.21)
# Iter 87: Acc train 0.8% (0.21), acc test 0.8% (0.21)
# Iter 88: Acc train 0.8% (0.21), acc test 0.8% (0.21)
# Iter 89: Acc train 0.8% (0.21), acc test 0.8% (0.21)
# Iter 90: Acc train 0.8% (0.21), acc test 0.8% (0.21)
# Iter 91: Acc train 0.8% (0.21), acc test 0.8% (0.21)
# Iter 92: Acc train 0.8% (0.21), acc test 0.8% (0.21)
# Iter 93: Acc train 0.8% (0.21), acc test 0.8% (0.21)
# Iter 94: Acc train 0.8% (0.21), acc test 0.8% (0.21)
# Iter 95: Acc train 0.8% (0.21), acc test 0.8% (0.21)
# Iter 96: Acc train 0.8% (0.21), acc test 0.8% (0.21)
# Iter 97: Acc train 0.8% (0.21), acc test 0.8% (0.21)
# Iter 98: Acc train 0.8% (0.21), acc test 0.8% (0.20)
# Iter 99: Acc train 0.8% (0.20), acc test 0.8% (0.20)
# Iter 100: Acc train 0.8% (0.20), acc test 0.8% (0.20)
# Iter 101: Acc train 0.8% (0.20), acc test 0.8% (0.20)
# Iter 102: Acc train 0.8% (0.20), acc test 0.8% (0.20)
# Iter 103: Acc train 0.8% (0.20), acc test 0.8% (0.20)
# Iter 104: Acc train 0.8% (0.20), acc test 0.8% (0.20)
# Iter 105: Acc train 0.8% (0.20), acc test 0.8% (0.20)
# Iter 106: Acc train 0.8% (0.20), acc test 0.8% (0.20)
# Iter 107: Acc train 0.8% (0.20), acc test 0.8% (0.20)
# Iter 108: Acc train 0.8% (0.20), acc test 0.9% (0.20)
# Iter 109: Acc train 0.8% (0.19), acc test 0.8% (0.19)
# Iter 110: Acc train 0.8% (0.19), acc test 0.9% (0.19)
# Iter 111: Acc train 0.8% (0.19), acc test 0.9% (0.19)
# Iter 112: Acc train 0.8% (0.19), acc test 0.8% (0.19)
# Iter 113: Acc train 0.8% (0.19), acc test 0.8% (0.19)
# Iter 114: Acc train 0.8% (0.19), acc test 0.8% (0.19)
# Iter 115: Acc train 0.8% (0.19), acc test 0.9% (0.19)
# Iter 116: Acc train 0.8% (0.19), acc test 0.9% (0.19)
# Iter 117: Acc train 0.8% (0.19), acc test 0.9% (0.19)
# Iter 118: Acc train 0.9% (0.19), acc test 0.9% (0.18)
# Iter 119: Acc train 0.9% (0.18), acc test 0.9% (0.18)
# Iter 120: Acc train 0.9% (0.18), acc test 0.9% (0.18)
# Iter 121: Acc train 0.8% (0.18), acc test 0.9% (0.18)
# Iter 122: Acc train 0.9% (0.18), acc test 0.9% (0.18)
# Iter 123: Acc train 0.9% (0.18), acc test 0.9% (0.18)
# Iter 124: Acc train 0.9% (0.18), acc test 0.9% (0.18)
# Iter 125: Acc train 0.9% (0.18), acc test 0.9% (0.18)
# Iter 126: Acc train 0.9% (0.18), acc test 0.9% (0.18)
# Iter 127: Acc train 0.9% (0.18), acc test 0.9% (0.18)
# Iter 128: Acc train 0.9% (0.18), acc test 0.9% (0.17)
# Iter 129: Acc train 0.9% (0.17), acc test 0.9% (0.17)
# Iter 130: Acc train 0.9% (0.17), acc test 0.9% (0.17)
# Iter 131: Acc train 0.9% (0.17), acc test 0.9% (0.17)
# Iter 132: Acc train 0.9% (0.17), acc test 0.9% (0.17)
# Iter 133: Acc train 0.9% (0.17), acc test 0.9% (0.17)
# Iter 134: Acc train 0.9% (0.17), acc test 0.9% (0.17)
# Iter 135: Acc train 0.9% (0.17), acc test 0.9% (0.17)
# Iter 136: Acc train 0.9% (0.17), acc test 0.9% (0.17)
# Iter 137: Acc train 0.9% (0.17), acc test 0.9% (0.16)
# Iter 138: Acc train 0.9% (0.16), acc test 0.9% (0.16)
# Iter 139: Acc train 0.9% (0.16), acc test 0.9% (0.16)
# Iter 140: Acc train 0.9% (0.16), acc test 0.9% (0.16)
# Iter 141: Acc train 0.9% (0.16), acc test 0.9% (0.16)
# Iter 142: Acc train 0.9% (0.16), acc test 0.9% (0.16)
# Iter 143: Acc train 0.9% (0.16), acc test 0.9% (0.16)
# Iter 144: Acc train 0.9% (0.16), acc test 0.9% (0.16)
# Iter 145: Acc train 0.9% (0.16), acc test 0.9% (0.16)
# Iter 146: Acc train 0.9% (0.16), acc test 0.9% (0.15)
# Iter 147: Acc train 0.9% (0.15), acc test 0.9% (0.15)
# Iter 148: Acc train 0.9% (0.15), acc test 0.9% (0.15)
# Iter 149: Acc train 0.9% (0.15), acc test 0.9% (0.15)

# %% [markdown]
# # Part 4 : Simplification of the SGD with `torch.optim`

# %%
def init_model(nx, nh, ny, eta):

    #####################
    ## Your code here  ##
    #####################

    model = torch.nn.Sequential(
        torch.nn.Linear(nx,nh),
        torch.nn.Tanh(),
        torch.nn.Linear(nh,ny),
        torch.nn.Softmax())
    loss = torch.nn.MSELoss()
    optim = torch.optim.SGD(model.parameters(), lr=eta)

    ####################
    ##      END        #
    ####################

    return model, loss, optim

# %% [markdown]
# The `sgd` function is replaced by calling the `optim.zero_grad()` before the backward and `optim.step()` after.

# %% [markdown]
# ## Algorithme global d'apprentissage (avec autograd, les couches `torch.nn` et `torch.optim`)

# %%
# init
data = CirclesData()
data.plot_data()
N = data.Xtrain.shape[0]
Nbatch = 10
nx = data.Xtrain.shape[1]
nh = 10
ny = data.Ytrain.shape[1]
eta = 0.03

model, loss, optim = init_model(nx, nh, ny, eta)

curves = [[],[], [], []]

# epoch
for iteration in range(150):

    # permute
    perm = np.random.permutation(N)
    Xtrain = data.Xtrain[perm, :]
    Ytrain = data.Ytrain[perm, :]

    #####################
    ## Your code  here ##
    #####################
    # batches
    for j in range(N // Nbatch):

        indsBatch = range(j * Nbatch, (j+1) * Nbatch)
        X = Xtrain[indsBatch, :]
        Y = Ytrain[indsBatch, :]
  
        # write the optimization algorithm on the batch (X,Y)
        # using the functions: loss_accuracy
        # the forward with the predict method from the model
        # the backward function with autograd
        # and then an optimization step
        Yhat = model(X)
        L, acc = loss_accuracy(loss, Yhat, Y)
        L.backward()
        optim.step()
        optim.zero_grad()

    ####################
    ##      FIN        #
    ####################


    Yhat_train = model(data.Xtrain)
    Yhat_test = model(data.Xtest)
    Ltrain, acctrain = loss_accuracy(loss, Yhat_train, data.Ytrain)
    Ltest, acctest = loss_accuracy(loss, Yhat_test, data.Ytest)
    Ygrid = model(data.Xgrid)  

    title = 'Iter {}: Acc train {:.1f}% ({:.2f}), acc test {:.1f}% ({:.2f})'.format(iteration, acctrain, Ltrain, acctest, Ltest)
    print(title) 

    curves[0].append(acctrain)
    curves[1].append(acctest)
    curves[2].append(Ltrain.detach().numpy())
    curves[3].append(Ltest.detach().numpy())

data.plot_data_with_grid(torch.nn.Softmax(dim=1)(Ygrid.detach()), title)
fig = plt.figure()
plt.plot(curves[0], label="acc. train")
plt.plot(curves[1], label="acc. test")
plt.plot(curves[2], label="loss train")
plt.plot(curves[3], label="loss test")
plt.legend()
plt.show()
# Out:
# Iter 0: Acc train 0.6% (0.27), acc test 0.6% (0.26)
# Iter 1: Acc train 0.6% (0.26), acc test 0.6% (0.26)
# Iter 2: Acc train 0.6% (0.26), acc test 0.6% (0.26)
# Iter 3: Acc train 0.6% (0.26), acc test 0.6% (0.26)
# Iter 4: Acc train 0.6% (0.26), acc test 0.6% (0.26)
# Iter 5: Acc train 0.6% (0.26), acc test 0.6% (0.26)
# Iter 6: Acc train 0.6% (0.26), acc test 0.6% (0.26)
# Iter 7: Acc train 0.6% (0.26), acc test 0.6% (0.25)
# Iter 8: Acc train 0.6% (0.26), acc test 0.6% (0.25)
# Iter 9: Acc train 0.6% (0.25), acc test 0.6% (0.25)
# Iter 10: Acc train 0.6% (0.25), acc test 0.6% (0.25)
# Iter 11: Acc train 0.6% (0.25), acc test 0.6% (0.25)
# Iter 12: Acc train 0.6% (0.25), acc test 0.6% (0.25)
# Iter 13: Acc train 0.6% (0.25), acc test 0.6% (0.25)
# Iter 14: Acc train 0.6% (0.25), acc test 0.6% (0.25)
# Iter 15: Acc train 0.5% (0.25), acc test 0.5% (0.25)
# Iter 16: Acc train 0.5% (0.25), acc test 0.5% (0.25)
# Iter 17: Acc train 0.5% (0.25), acc test 0.5% (0.25)
# Iter 18: Acc train 0.5% (0.25), acc test 0.5% (0.25)
# Iter 19: Acc train 0.5% (0.25), acc test 0.5% (0.25)
# Iter 20: Acc train 0.5% (0.25), acc test 0.5% (0.25)
# Iter 21: Acc train 0.5% (0.25), acc test 0.5% (0.25)
# Iter 22: Acc train 0.5% (0.25), acc test 0.5% (0.25)
# Iter 23: Acc train 0.5% (0.25), acc test 0.5% (0.25)
# Iter 24: Acc train 0.6% (0.25), acc test 0.5% (0.25)
# Iter 25: Acc train 0.6% (0.25), acc test 0.5% (0.25)
# Iter 26: Acc train 0.6% (0.25), acc test 0.6% (0.25)
# Iter 27: Acc train 0.6% (0.25), acc test 0.6% (0.25)
# Iter 28: Acc train 0.6% (0.25), acc test 0.6% (0.25)
# Iter 29: Acc train 0.6% (0.25), acc test 0.6% (0.25)
# Iter 30: Acc train 0.6% (0.25), acc test 0.6% (0.25)
# Iter 31: Acc train 0.6% (0.25), acc test 0.6% (0.25)
# Iter 32: Acc train 0.6% (0.25), acc test 0.6% (0.25)
# Iter 33: Acc train 0.6% (0.25), acc test 0.6% (0.25)
# Iter 34: Acc train 0.7% (0.25), acc test 0.6% (0.25)
# Iter 35: Acc train 0.7% (0.25), acc test 0.6% (0.25)
# Iter 36: Acc train 0.7% (0.25), acc test 0.6% (0.25)
# Iter 37: Acc train 0.7% (0.25), acc test 0.6% (0.25)
# Iter 38: Acc train 0.7% (0.25), acc test 0.6% (0.25)
# Iter 39: Acc train 0.7% (0.25), acc test 0.7% (0.25)
# Iter 40: Acc train 0.7% (0.25), acc test 0.7% (0.25)
# Iter 41: Acc train 0.7% (0.24), acc test 0.7% (0.25)
# Iter 42: Acc train 0.7% (0.24), acc test 0.7% (0.25)
# Iter 43: Acc train 0.7% (0.24), acc test 0.6% (0.25)
# Iter 44: Acc train 0.7% (0.24), acc test 0.7% (0.25)
# Iter 45: Acc train 0.7% (0.24), acc test 0.7% (0.25)
# Iter 46: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 47: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 48: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 49: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 50: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 51: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 52: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 53: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 54: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 55: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 56: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 57: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 58: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 59: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 60: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 61: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 62: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 63: Acc train 0.7% (0.24), acc test 0.7% (0.24)
# Iter 64: Acc train 0.8% (0.24), acc test 0.7% (0.24)
# Iter 65: Acc train 0.8% (0.24), acc test 0.8% (0.24)
# Iter 66: Acc train 0.8% (0.24), acc test 0.8% (0.24)
# Iter 67: Acc train 0.8% (0.24), acc test 0.8% (0.24)
# Iter 68: Acc train 0.8% (0.23), acc test 0.8% (0.24)
# Iter 69: Acc train 0.8% (0.23), acc test 0.8% (0.24)
# Iter 70: Acc train 0.8% (0.23), acc test 0.8% (0.24)
# Iter 71: Acc train 0.8% (0.23), acc test 0.8% (0.24)
# Iter 72: Acc train 0.8% (0.23), acc test 0.8% (0.24)
# Iter 73: Acc train 0.8% (0.23), acc test 0.8% (0.23)
# Iter 74: Acc train 0.8% (0.23), acc test 0.7% (0.23)
# Iter 75: Acc train 0.8% (0.23), acc test 0.8% (0.23)
# Iter 76: Acc train 0.8% (0.23), acc test 0.7% (0.23)
# Iter 77: Acc train 0.8% (0.23), acc test 0.7% (0.23)
# Iter 78: Acc train 0.8% (0.23), acc test 0.7% (0.23)
# Iter 79: Acc train 0.8% (0.23), acc test 0.7% (0.23)
# Iter 80: Acc train 0.8% (0.23), acc test 0.7% (0.23)
# Iter 81: Acc train 0.8% (0.23), acc test 0.7% (0.23)
# Iter 82: Acc train 0.8% (0.23), acc test 0.7% (0.23)
# Iter 83: Acc train 0.8% (0.23), acc test 0.7% (0.23)
# Iter 84: Acc train 0.8% (0.23), acc test 0.7% (0.23)
# Iter 85: Acc train 0.8% (0.23), acc test 0.7% (0.23)
# Iter 86: Acc train 0.8% (0.22), acc test 0.7% (0.23)
# Iter 87: Acc train 0.8% (0.22), acc test 0.7% (0.23)
# Iter 88: Acc train 0.8% (0.22), acc test 0.7% (0.23)
# Iter 89: Acc train 0.8% (0.22), acc test 0.8% (0.23)
# Iter 90: Acc train 0.8% (0.22), acc test 0.8% (0.23)
# Iter 91: Acc train 0.8% (0.22), acc test 0.8% (0.22)
# Iter 92: Acc train 0.8% (0.22), acc test 0.8% (0.22)
# Iter 93: Acc train 0.8% (0.22), acc test 0.8% (0.22)
# Iter 94: Acc train 0.8% (0.22), acc test 0.8% (0.22)
# Iter 95: Acc train 0.8% (0.22), acc test 0.8% (0.22)
# Iter 96: Acc train 0.8% (0.22), acc test 0.8% (0.22)
# Iter 97: Acc train 0.8% (0.22), acc test 0.8% (0.22)
# Iter 98: Acc train 0.8% (0.22), acc test 0.8% (0.22)
# Iter 99: Acc train 0.8% (0.21), acc test 0.8% (0.22)
# Iter 100: Acc train 0.8% (0.21), acc test 0.8% (0.22)
# Iter 101: Acc train 0.8% (0.21), acc test 0.8% (0.22)
# Iter 102: Acc train 0.8% (0.21), acc test 0.8% (0.22)
# Iter 103: Acc train 0.8% (0.21), acc test 0.8% (0.22)
# Iter 104: Acc train 0.8% (0.21), acc test 0.8% (0.22)
# Iter 105: Acc train 0.8% (0.21), acc test 0.8% (0.21)
# Iter 106: Acc train 0.8% (0.21), acc test 0.8% (0.21)
# Iter 107: Acc train 0.8% (0.21), acc test 0.8% (0.21)
# Iter 108: Acc train 0.8% (0.21), acc test 0.8% (0.21)
# Iter 109: Acc train 0.8% (0.21), acc test 0.8% (0.21)
# Iter 110: Acc train 0.8% (0.21), acc test 0.8% (0.21)
# Iter 111: Acc train 0.8% (0.20), acc test 0.8% (0.21)
# Iter 112: Acc train 0.8% (0.20), acc test 0.8% (0.21)
# Iter 113: Acc train 0.8% (0.20), acc test 0.8% (0.21)
# Iter 114: Acc train 0.8% (0.20), acc test 0.8% (0.21)
# Iter 115: Acc train 0.8% (0.20), acc test 0.8% (0.21)
# Iter 116: Acc train 0.8% (0.20), acc test 0.8% (0.21)
# Iter 117: Acc train 0.8% (0.20), acc test 0.8% (0.21)
# Iter 118: Acc train 0.8% (0.20), acc test 0.8% (0.21)
# Iter 119: Acc train 0.8% (0.20), acc test 0.8% (0.20)
# Iter 120: Acc train 0.8% (0.20), acc test 0.8% (0.20)
# Iter 121: Acc train 0.8% (0.20), acc test 0.8% (0.20)
# Iter 122: Acc train 0.8% (0.20), acc test 0.8% (0.20)
# Iter 123: Acc train 0.8% (0.19), acc test 0.8% (0.20)
# Iter 124: Acc train 0.8% (0.19), acc test 0.8% (0.20)
# Iter 125: Acc train 0.8% (0.19), acc test 0.8% (0.20)
# Iter 126: Acc train 0.8% (0.19), acc test 0.8% (0.20)
# Iter 127: Acc train 0.8% (0.19), acc test 0.8% (0.20)
# Iter 128: Acc train 0.8% (0.19), acc test 0.8% (0.20)
# Iter 129: Acc train 0.8% (0.19), acc test 0.8% (0.20)
# Iter 130: Acc train 0.8% (0.19), acc test 0.8% (0.20)
# Iter 131: Acc train 0.8% (0.19), acc test 0.8% (0.20)
# Iter 132: Acc train 0.8% (0.19), acc test 0.8% (0.20)
# Iter 133: Acc train 0.8% (0.19), acc test 0.8% (0.20)
# Iter 134: Acc train 0.8% (0.19), acc test 0.8% (0.19)
# Iter 135: Acc train 0.8% (0.18), acc test 0.8% (0.19)
# Iter 136: Acc train 0.8% (0.18), acc test 0.8% (0.19)
# Iter 137: Acc train 0.8% (0.18), acc test 0.8% (0.19)
# Iter 138: Acc train 0.8% (0.18), acc test 0.8% (0.19)
# Iter 139: Acc train 0.8% (0.18), acc test 0.8% (0.19)
# Iter 140: Acc train 0.8% (0.18), acc test 0.8% (0.19)
# Iter 141: Acc train 0.8% (0.18), acc test 0.8% (0.19)
# Iter 142: Acc train 0.8% (0.18), acc test 0.8% (0.19)
# Iter 143: Acc train 0.8% (0.18), acc test 0.8% (0.19)
# Iter 144: Acc train 0.8% (0.18), acc test 0.8% (0.19)
# Iter 145: Acc train 0.8% (0.18), acc test 0.8% (0.19)
# Iter 146: Acc train 0.8% (0.18), acc test 0.8% (0.19)
# Iter 147: Acc train 0.8% (0.18), acc test 0.8% (0.19)
# Iter 148: Acc train 0.8% (0.18), acc test 0.8% (0.19)
# Iter 149: Acc train 0.8% (0.17), acc test 0.8% (0.19)

# %% [markdown]
# # Part 5 : MNIST

# %% [markdown]
# Apply the code from previous part code to the MNIST dataset.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
learning_rates = np.logspace(-4, -1, num=8)
nhs = np.logspace(5, 11, num=7, base=2)
n_batchs = np.arange(50, 251, 50)

print(learning_rates)
print(nhs)
print(n_batchs)

n_epoch = 20
# Out:
# [0.0001     0.00026827 0.00071969 0.0019307  0.00517947 0.01389495
#  0.03727594 0.1       ]
# [  32.   64.  128.  256.  512. 1024. 2048.]
# [ 50 100 150 200 250]

# %%
## TEST LEARNING RATES

# init
data = MNISTData()
N = data.Xtrain.shape[0]
nx = data.Xtrain.shape[1]
ny = data.Ytrain.shape[1]
nh = 100
Nbatch = 100
all_curves = []

for eta in learning_rates:
    model, loss, optim = init_model(nx, nh, ny, eta)

    curves = [[],[], [], []]

    model = model.to(device)
    X_train = data.Xtrain.to(device)
    y_train = data.Ytrain.to(device)
    X_test = data.Xtest.to(device)
    y_test = data.Ytest.to(device)

    for iteration in range(n_epoch):

        perm = np.random.permutation(N)
        Xtrain = X_train[perm, :]
        Ytrain = y_train[perm, :]

        for j in range(N // Nbatch):

            indsBatch = range(j * Nbatch, (j+1) * Nbatch)
            X = Xtrain[indsBatch, :]
            Y = Ytrain[indsBatch, :]

            Yhat = model(X)
            L, acc = loss_accuracy(loss, Yhat, Y)
            L.backward()
            optim.step()
            optim.zero_grad()

        Yhat_train = model(X_train)
        Yhat_test = model(X_test)
        Ltrain, acctrain = loss_accuracy(loss, Yhat_train, y_train)
        Ltest, acctest = loss_accuracy(loss, Yhat_test, y_test)

        title = 'Iter {}: Acc train {:.1f}% ({:.2f}), acc test {:.1f}% ({:.2f})'.format(iteration, acctrain, Ltrain, acctest, Ltest)
        print(title)

        curves[0].append(acctrain.cpu())
        curves[1].append(acctest.cpu())
        curves[2].append(Ltrain.detach().cpu().numpy())
        curves[3].append(Ltest.detach().cpu().numpy())
        
    all_curves.append(curves)
    
all_curves = np.array(all_curves)

fig = plt.figure(figsize=(10,10))
plt.title("Accuracy")
for i in range(all_curves.shape[0]):
    plt.plot(all_curves[i,1], label="lr "+str(learning_rates[i])[:8])
plt.legend(loc="lower right")
plt.show()

fig = plt.figure(figsize=(10,10))
plt.title("Loss")
for i in range(all_curves.shape[0]):
    plt.plot(all_curves[i,3], label="lr "+str(learning_rates[i])[:8])
plt.legend(loc="upper right")
plt.show()
# Out:
# Iter 0: Acc train 0.1% (0.09), acc test 0.1% (0.09)
# Iter 1: Acc train 0.1% (0.09), acc test 0.1% (0.09)
# Iter 2: Acc train 0.1% (0.09), acc test 0.1% (0.09)
# Iter 3: Acc train 0.2% (0.09), acc test 0.2% (0.09)
# Iter 4: Acc train 0.2% (0.09), acc test 0.2% (0.09)
# Iter 5: Acc train 0.2% (0.09), acc test 0.2% (0.09)
# Iter 6: Acc train 0.2% (0.09), acc test 0.2% (0.09)
# Iter 7: Acc train 0.2% (0.09), acc test 0.2% (0.09)
# Iter 8: Acc train 0.2% (0.09), acc test 0.2% (0.09)
# Iter 9: Acc train 0.2% (0.09), acc test 0.2% (0.09)
# Iter 10: Acc train 0.2% (0.09), acc test 0.2% (0.09)
# Iter 11: Acc train 0.2% (0.09), acc test 0.2% (0.09)
# Iter 12: Acc train 0.2% (0.09), acc test 0.3% (0.09)
# Iter 13: Acc train 0.3% (0.09), acc test 0.3% (0.09)
# Iter 14: Acc train 0.3% (0.09), acc test 0.3% (0.09)
# Iter 15: Acc train 0.3% (0.08), acc test 0.3% (0.08)
# Iter 16: Acc train 0.3% (0.08), acc test 0.3% (0.08)
# Iter 17: Acc train 0.3% (0.08), acc test 0.3% (0.08)
# Iter 18: Acc train 0.3% (0.08), acc test 0.3% (0.08)
# Iter 19: Acc train 0.3% (0.08), acc test 0.3% (0.08)
# Iter 0: Acc train 0.2% (0.09), acc test 0.2% (0.09)
# Iter 1: Acc train 0.2% (0.09), acc test 0.2% (0.09)
# Iter 2: Acc train 0.2% (0.09), acc test 0.2% (0.09)
# Iter 3: Acc train 0.2% (0.09), acc test 0.3% (0.09)
# Iter 4: Acc train 0.3% (0.08), acc test 0.3% (0.08)
# Iter 5: Acc train 0.3% (0.08), acc test 0.3% (0.08)
# Iter 6: Acc train 0.4% (0.08), acc test 0.4% (0.08)
# Iter 7: Acc train 0.4% (0.08), acc test 0.4% (0.08)
# Iter 8: Acc train 0.4% (0.08), acc test 0.4% (0.08)
# Iter 9: Acc train 0.4% (0.08), acc test 0.4% (0.08)
# Iter 10: Acc train 0.4% (0.08), acc test 0.4% (0.08)
# Iter 11: Acc train 0.5% (0.08), acc test 0.5% (0.08)
# Iter 12: Acc train 0.5% (0.07), acc test 0.5% (0.07)
# Iter 13: Acc train 0.5% (0.07), acc test 0.5% (0.07)
# Iter 14: Acc train 0.5% (0.07), acc test 0.5% (0.07)
# Iter 15: Acc train 0.5% (0.07), acc test 0.5% (0.07)
# Iter 16: Acc train 0.5% (0.07), acc test 0.5% (0.07)
# Iter 17: Acc train 0.5% (0.07), acc test 0.5% (0.07)
# Iter 18: Acc train 0.6% (0.07), acc test 0.6% (0.07)
# Iter 19: Acc train 0.6% (0.07), acc test 0.6% (0.07)
# Iter 0: Acc train 0.1% (0.09), acc test 0.1% (0.09)
# Iter 1: Acc train 0.2% (0.09), acc test 0.2% (0.09)
# Iter 2: Acc train 0.2% (0.09), acc test 0.2% (0.09)
# Iter 3: Acc train 0.3% (0.08), acc test 0.3% (0.08)
# Iter 4: Acc train 0.3% (0.08), acc test 0.3% (0.08)
# Iter 5: Acc train 0.4% (0.08), acc test 0.4% (0.08)
# Iter 6: Acc train 0.4% (0.07), acc test 0.4% (0.07)
# Iter 7: Acc train 0.5% (0.07), acc test 0.5% (0.07)
# Iter 8: Acc train 0.5% (0.07), acc test 0.5% (0.07)
# Iter 9: Acc train 0.5% (0.07), acc test 0.5% (0.07)
# Iter 10: Acc train 0.6% (0.07), acc test 0.6% (0.07)
# Iter 11: Acc train 0.6% (0.06), acc test 0.6% (0.06)
# Iter 12: Acc train 0.6% (0.06), acc test 0.6% (0.06)
# Iter 13: Acc train 0.6% (0.06), acc test 0.6% (0.06)
# Iter 14: Acc train 0.7% (0.06), acc test 0.7% (0.06)
# Iter 15: Acc train 0.7% (0.06), acc test 0.7% (0.06)
# Iter 16: Acc train 0.7% (0.05), acc test 0.7% (0.05)
# Iter 17: Acc train 0.7% (0.05), acc test 0.7% (0.05)
# Iter 18: Acc train 0.7% (0.05), acc test 0.7% (0.05)
# Iter 19: Acc train 0.7% (0.05), acc test 0.7% (0.05)
# Iter 0: Acc train 0.3% (0.08), acc test 0.3% (0.08)
# Iter 1: Acc train 0.5% (0.08), acc test 0.5% (0.08)
# Iter 2: Acc train 0.6% (0.07), acc test 0.6% (0.07)
# Iter 3: Acc train 0.6% (0.06), acc test 0.6% (0.06)
# Iter 4: Acc train 0.7% (0.06), acc test 0.7% (0.06)
# Iter 5: Acc train 0.7% (0.05), acc test 0.7% (0.05)
# Iter 6: Acc train 0.7% (0.05), acc test 0.7% (0.05)
# Iter 7: Acc train 0.7% (0.05), acc test 0.7% (0.05)
# Iter 8: Acc train 0.8% (0.04), acc test 0.8% (0.04)
# Iter 9: Acc train 0.8% (0.04), acc test 0.8% (0.04)
# Iter 10: Acc train 0.8% (0.04), acc test 0.8% (0.04)
# Iter 11: Acc train 0.8% (0.04), acc test 0.8% (0.04)
# Iter 12: Acc train 0.8% (0.03), acc test 0.8% (0.03)
# Iter 13: Acc train 0.8% (0.03), acc test 0.8% (0.03)
# Iter 14: Acc train 0.8% (0.03), acc test 0.8% (0.03)
# Iter 15: Acc train 0.8% (0.03), acc test 0.8% (0.03)
# Iter 16: Acc train 0.8% (0.03), acc test 0.8% (0.03)
# Iter 17: Acc train 0.9% (0.03), acc test 0.9% (0.03)
# Iter 18: Acc train 0.9% (0.03), acc test 0.9% (0.03)
# Iter 19: Acc train 0.9% (0.03), acc test 0.9% (0.03)
# Iter 0: Acc train 0.5% (0.07), acc test 0.5% (0.07)
# Iter 1: Acc train 0.7% (0.05), acc test 0.7% (0.05)
# Iter 2: Acc train 0.7% (0.04), acc test 0.8% (0.04)
# Iter 3: Acc train 0.8% (0.04), acc test 0.8% (0.04)
# Iter 4: Acc train 0.8% (0.03), acc test 0.8% (0.03)
# Iter 5: Acc train 0.8% (0.03), acc test 0.8% (0.03)
# Iter 6: Acc train 0.8% (0.03), acc test 0.9% (0.03)
# Iter 7: Acc train 0.9% (0.03), acc test 0.9% (0.03)
# Iter 8: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 9: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 10: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 11: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 12: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 13: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 14: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 15: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 16: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 17: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 18: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 19: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 0: Acc train 0.7% (0.05), acc test 0.7% (0.05)
# Iter 1: Acc train 0.8% (0.03), acc test 0.8% (0.03)
# Iter 2: Acc train 0.9% (0.03), acc test 0.9% (0.03)
# Iter 3: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 4: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 5: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 6: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 7: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 8: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 9: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 10: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 11: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 12: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 13: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 14: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 15: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 16: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 17: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 18: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 19: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 0: Acc train 0.8% (0.03), acc test 0.8% (0.03)
# Iter 1: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 2: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 3: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 4: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 5: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 6: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 7: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 8: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 9: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 10: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 11: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 12: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 13: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 14: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 15: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 16: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 17: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 18: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 19: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 0: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 1: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 2: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 3: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 4: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 5: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 6: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 7: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 8: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 9: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 10: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 11: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 12: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 13: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 14: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 15: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 16: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 17: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 18: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 19: Acc train 0.9% (0.01), acc test 0.9% (0.01)

# %%
## TEST BATCH_SIZE

# init
data = MNISTData()
N = data.Xtrain.shape[0]
nx = data.Xtrain.shape[1]
ny = data.Ytrain.shape[1]
nh = 100
eta = 0.03
all_curves = []

for Nbatch in n_batchs:
    model, loss, optim = init_model(nx, nh, ny, eta)

    curves = [[],[], [], []]

    model = model.to(device)
    X_train = data.Xtrain.to(device)
    y_train = data.Ytrain.to(device)
    X_test = data.Xtest.to(device)
    y_test = data.Ytest.to(device)

    for iteration in range(n_epoch):

        perm = np.random.permutation(N)
        Xtrain = X_train[perm, :]
        Ytrain = y_train[perm, :]

        for j in range(N // Nbatch):

            indsBatch = range(j * Nbatch, (j+1) * Nbatch)
            X = Xtrain[indsBatch, :]
            Y = Ytrain[indsBatch, :]

            Yhat = model(X)
            L, acc = loss_accuracy(loss, Yhat, Y)
            L.backward()
            optim.step()
            optim.zero_grad()

        Yhat_train = model(X_train)
        Yhat_test = model(X_test)
        Ltrain, acctrain = loss_accuracy(loss, Yhat_train, y_train)
        Ltest, acctest = loss_accuracy(loss, Yhat_test, y_test)

        title = 'Iter {}: Acc train {:.1f}% ({:.2f}), acc test {:.1f}% ({:.2f})'.format(iteration, acctrain, Ltrain, acctest, Ltest)
        print(title)

        curves[0].append(acctrain.cpu())
        curves[1].append(acctest.cpu())
        curves[2].append(Ltrain.detach().cpu().numpy())
        curves[3].append(Ltest.detach().cpu().numpy())
        
    all_curves.append(curves)
    
all_curves = np.array(all_curves)

fig = plt.figure(figsize=(10,10))
plt.title("Accuracy")
for i in range(all_curves.shape[0]):
    plt.plot(all_curves[i,1], label="n batch "+str(n_batchs[i]))
plt.legend(loc="lower right")
plt.show()

fig = plt.figure(figsize=(10,10))
plt.title("Loss")
for i in range(all_curves.shape[0]):
    plt.plot(all_curves[i,3], label="n batch "+str(n_batchs[i]))
plt.legend(loc="upper right")
plt.show()
# Out:
# Iter 0: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 1: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 2: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 3: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 4: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 5: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 6: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 7: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 8: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 9: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 10: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 11: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 12: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 13: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 14: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 15: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 16: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 17: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 18: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 19: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 0: Acc train 0.8% (0.04), acc test 0.8% (0.03)
# Iter 1: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 2: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 3: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 4: Acc train 0.9% (0.02), acc test 0.9% (0.01)
# Iter 5: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 6: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 7: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 8: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 9: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 10: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 11: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 12: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 13: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 14: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 15: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 16: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 17: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 18: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 19: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 0: Acc train 0.8% (0.04), acc test 0.8% (0.04)
# Iter 1: Acc train 0.9% (0.03), acc test 0.9% (0.03)
# Iter 2: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 3: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 4: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 5: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 6: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 7: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 8: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 9: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 10: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 11: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 12: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 13: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 14: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 15: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 16: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 17: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 18: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 19: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 0: Acc train 0.7% (0.05), acc test 0.7% (0.05)
# Iter 1: Acc train 0.8% (0.03), acc test 0.8% (0.03)
# Iter 2: Acc train 0.9% (0.03), acc test 0.9% (0.03)
# Iter 3: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 4: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 5: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 6: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 7: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 8: Acc train 0.9% (0.01), acc test 0.9% (0.02)
# Iter 9: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 10: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 11: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 12: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 13: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 14: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 15: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 16: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 17: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 18: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 19: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 0: Acc train 0.6% (0.06), acc test 0.6% (0.06)
# Iter 1: Acc train 0.8% (0.04), acc test 0.8% (0.04)
# Iter 2: Acc train 0.9% (0.03), acc test 0.9% (0.03)
# Iter 3: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 4: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 5: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 6: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 7: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 8: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 9: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 10: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 11: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 12: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 13: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 14: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 15: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 16: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 17: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 18: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 19: Acc train 0.9% (0.01), acc test 0.9% (0.01)

# %%
## TEST NH

# init
data = MNISTData()
N = data.Xtrain.shape[0]
nx = data.Xtrain.shape[1]
ny = data.Ytrain.shape[1]
Nbatch = 100
all_curves = []
eta = 0.03

for nh in nhs:
    model, loss, optim = init_model(nx, int(nh), ny, eta)

    curves = [[],[], [], []]

    model = model.to(device)
    X_train = data.Xtrain.to(device)
    y_train = data.Ytrain.to(device)
    X_test = data.Xtest.to(device)
    y_test = data.Ytest.to(device)

    for iteration in range(n_epoch):

        perm = np.random.permutation(N)
        Xtrain = X_train[perm, :]
        Ytrain = y_train[perm, :]

        for j in range(N // Nbatch):

            indsBatch = range(j * Nbatch, (j+1) * Nbatch)
            X = Xtrain[indsBatch, :]
            Y = Ytrain[indsBatch, :]

            Yhat = model(X)
            L, acc = loss_accuracy(loss, Yhat, Y)
            L.backward()
            optim.step()
            optim.zero_grad()

        Yhat_train = model(X_train)
        Yhat_test = model(X_test)
        Ltrain, acctrain = loss_accuracy(loss, Yhat_train, y_train)
        Ltest, acctest = loss_accuracy(loss, Yhat_test, y_test)

        title = 'Iter {}: Acc train {:.1f}% ({:.2f}), acc test {:.1f}% ({:.2f})'.format(iteration, acctrain, Ltrain, acctest, Ltest)
        print(title)

        curves[0].append(acctrain.cpu())
        curves[1].append(acctest.cpu())
        curves[2].append(Ltrain.detach().cpu().numpy())
        curves[3].append(Ltest.detach().cpu().numpy())
        
    all_curves.append(curves)
    
all_curves = np.array(all_curves)

fig = plt.figure(figsize=(10,10))
plt.title("Accuracy")
for i in range(all_curves.shape[0]):
    plt.plot(all_curves[i,1], label="hidden neurons "+str(nhs[i]))
plt.legend(loc="lower right")
plt.show()

fig = plt.figure(figsize=(10,10))
plt.title("Loss")
for i in range(all_curves.shape[0]):
    plt.plot(all_curves[i,3], label="hidden neurons "+str(nhs[i]))
plt.legend(loc="upper right")
plt.show()
# Out:
# Iter 0: Acc train 0.8% (0.05), acc test 0.8% (0.04)
# Iter 1: Acc train 0.8% (0.03), acc test 0.8% (0.03)
# Iter 2: Acc train 0.9% (0.03), acc test 0.9% (0.03)
# Iter 3: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 4: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 5: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 6: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 7: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 8: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 9: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 10: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 11: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 12: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 13: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 14: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 15: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 16: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 17: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 18: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 19: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 0: Acc train 0.8% (0.04), acc test 0.8% (0.04)
# Iter 1: Acc train 0.9% (0.03), acc test 0.9% (0.02)
# Iter 2: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 3: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 4: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 5: Acc train 0.9% (0.02), acc test 0.9% (0.01)
# Iter 6: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 7: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 8: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 9: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 10: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 11: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 12: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 13: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 14: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 15: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 16: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 17: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 18: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 19: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 0: Acc train 0.8% (0.03), acc test 0.8% (0.03)
# Iter 1: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 2: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 3: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 4: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 5: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 6: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 7: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 8: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 9: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 10: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 11: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 12: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 13: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 14: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 15: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 16: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 17: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 18: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 19: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 0: Acc train 0.9% (0.03), acc test 0.9% (0.03)
# Iter 1: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 2: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 3: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 4: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 5: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 6: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 7: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 8: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 9: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 10: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 11: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 12: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 13: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 14: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 15: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 16: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 17: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 18: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 19: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 0: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 1: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 2: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 3: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 4: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 5: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 6: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 7: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 8: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 9: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 10: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 11: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 12: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 13: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 14: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 15: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 16: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 17: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 18: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 19: Acc train 1.0% (0.01), acc test 1.0% (0.01)
# Iter 0: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 1: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 2: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 3: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 4: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 5: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 6: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 7: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 8: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 9: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 10: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 11: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 12: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 13: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 14: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 15: Acc train 1.0% (0.00), acc test 0.9% (0.01)
# Iter 16: Acc train 1.0% (0.00), acc test 0.9% (0.01)
# Iter 17: Acc train 1.0% (0.00), acc test 0.9% (0.01)
# Iter 18: Acc train 1.0% (0.00), acc test 0.9% (0.01)
# Iter 19: Acc train 1.0% (0.00), acc test 0.9% (0.01)
# Iter 0: Acc train 0.9% (0.02), acc test 0.9% (0.02)
# Iter 1: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 2: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 3: Acc train 0.9% (0.01), acc test 0.9% (0.01)
# Iter 4: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 5: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 6: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 7: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 8: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 9: Acc train 1.0% (0.01), acc test 0.9% (0.01)
# Iter 10: Acc train 1.0% (0.00), acc test 0.9% (0.01)
# Iter 11: Acc train 1.0% (0.00), acc test 0.9% (0.01)
# Iter 12: Acc train 1.0% (0.00), acc test 0.9% (0.01)
# Iter 13: Acc train 1.0% (0.00), acc test 0.9% (0.01)
# Iter 14: Acc train 1.0% (0.00), acc test 0.9% (0.01)
# Iter 15: Acc train 1.0% (0.00), acc test 1.0% (0.01)
# Iter 16: Acc train 1.0% (0.00), acc test 0.9% (0.01)
# Iter 17: Acc train 1.0% (0.00), acc test 1.0% (0.01)
# Iter 18: Acc train 1.0% (0.00), acc test 1.0% (0.01)
# Iter 19: Acc train 1.0% (0.00), acc test 1.0% (0.01)

# %% [markdown]
# # Part 6: Bonus: SVM
#
#
# Train a SVM model on the Circles dataset.
#
# Ideas :
# - First try a linear SVM (sklearn.svm.LinearSVC dans scikit-learn). Does it work well ? Why ?
# - Then try more complex kernels (sklearn.svm.SVC). Which one is the best ? why ?
# - Does the parameter C of regularization have an impact? Why ?

# %%
# data
data = CirclesData()
Xtrain = data.Xtrain.numpy()
Ytrain = data.Ytrain[:, 0].numpy()

Xgrid = data.Xgrid.numpy()

Xtest = data.Xtest.numpy()
Ytest = data.Ytest[:, 0].numpy()

def plot_svm_predictions(data, predictions):
      plt.figure(2)
      plt.clf()
      plt.imshow(np.reshape(predictions, (40,40)))
      plt.plot(data._Xtrain[data._Ytrain[:,0] == 1,0]*10+20, data._Xtrain[data._Ytrain[:,0] == 1,1]*10+20, 'bo', label="Train")
      plt.plot(data._Xtrain[data._Ytrain[:,1] == 1,0]*10+20, data._Xtrain[data._Ytrain[:,1] == 1,1]*10+20, 'ro')
      plt.plot(data._Xtest[data._Ytest[:,0] == 1,0]*10+20, data._Xtest[data._Ytest[:,0] == 1,1]*10+20, 'b+', label="Test")
      plt.plot(data._Xtest[data._Ytest[:,1] == 1,0]*10+20, data._Xtest[data._Ytest[:,1] == 1,1]*10+20, 'r+')
      plt.xlim(0,39)
      plt.ylim(0,39)
      plt.clim(0.3,0.7)
      plt.draw()
      plt.pause(1e-3)

# %%
import sklearn.svm

############################
### Your code here   #######
### Train the SVM    #######
## See https://scikit-learn.org/stable/modules/generated/sklearn.svm.LinearSVC.html
## and https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
############################

svm = None

###########################

# %%
## Print results

Ytest_pred = svm.predict(Xtest)
accuracy = np.sum(Ytest == Ytest_pred) / len(Ytest)
print(f"Accuracy : {100 * accuracy:.2f}")
Ygrid_pred = svm.predict(Xgrid)
plot_svm_predictions(data, Ygrid_pred)
