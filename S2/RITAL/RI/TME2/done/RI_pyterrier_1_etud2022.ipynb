# %% [markdown]
# # Recherche d'information : librairie PyTerrier
#
# Dans cette partie, nous nous intéressons à la librairie [PyTerrier](https://pyterrier.readthedocs.io/en/latest/#) qui permet de mettre en place diverses briques d'un moteur de recherche.
# PyTerrier est basée sur [Terrier](http://terrier.org/) qui est un moteur de recherche développé en Java.
#
# Nous allons voir :
# *   l'installation et la configuration
# *   l'indexation d'une collection
# *   l'accès à l'index
# *   l'évaluation d'un moteur de recherche

# %% [markdown]
# ## Installation ete configuration
#
# Après l'installation de la librairie, il est nécessaire d'initialiser PyTerrier pour importer les fichiers jar et démarrer la machine virtuelle associée;

# %%
# !pip install python-terrier

import pyterrier as pt
if not pt.started():
  pt.init(boot_packages=["com.github.terrierteam:terrier-prf:-SNAPSHOT"])
# Out:
# Collecting python-terrier
#   Downloading python-terrier-0.8.0.tar.gz (97 kB)
#      |████████████████████████████████| 97 kB 3.6 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.21.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.3.5)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from python-terrier) (4.63.0)
# Collecting pyjnius~=1.3.0
#   Downloading pyjnius-1.3.0-cp37-cp37m-manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 24.1 MB/s
# Collecting matchpy
#   Downloading matchpy-0.5.5-py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 9.2 MB/s
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from python-terrier) (0.0)
# Collecting deprecation
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting chest
#   Downloading chest-0.2.3.tar.gz (9.6 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from python-terrier) (2.23.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.1.0)
# Collecting nptyping
#   Downloading nptyping-1.4.4-py3-none-any.whl (31 kB)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.7/dist-packages (from python-terrier) (8.12.0)
# Collecting ir_datasets>=0.3.2
#   Downloading ir_datasets-0.5.0-py3-none-any.whl (255 kB)
#      |████████████████████████████████| 255 kB 53.5 MB/s
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from python-terrier) (2.11.3)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (from python-terrier) (0.10.2)
# Collecting ir_measures>=0.2.0
#   Downloading ir_measures-0.2.3.tar.gz (41 kB)
#      |████████████████████████████████| 41 kB 369 kB/s
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from python-terrier) (0.3.4)
# Collecting warc3-wet>=0.2.3
#   Downloading warc3_wet-0.2.3-py3-none-any.whl (13 kB)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from ir_datasets>=0.3.2->python-terrier) (4.6.3)
# Collecting lxml>=4.5.2
#   Downloading lxml-4.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 22.9 MB/s
# Collecting ijson>=3.1.3
#   Downloading ijson-3.1.4-cp37-cp37m-manylinux2010_x86_64.whl (126 kB)
#      |████████████████████████████████| 126 kB 48.5 MB/s
# Collecting warc3-wet-clueweb09>=0.2.5
#   Downloading warc3-wet-clueweb09-0.2.5.tar.gz (17 kB)
# Collecting lz4>=3.1.1
#   Downloading lz4-4.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 55.9 MB/s
# Collecting trec-car-tools>=2.5.4
#   Downloading trec_car_tools-2.6-py3-none-any.whl (8.4 kB)
# Collecting zlib-state>=0.1.3
#   Downloading zlib_state-0.1.5-cp37-cp37m-manylinux2010_x86_64.whl (72 kB)
#      |████████████████████████████████| 72 kB 1.3 MB/s
# Collecting pyyaml>=5.3.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 9.9 MB/s
# Collecting pyautocorpus>=0.1.1
#   Downloading pyautocorpus-0.1.8-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (294 kB)
#      |████████████████████████████████| 294 kB 54.5 MB/s
# Collecting pytrec-eval-terrier==0.5.1
#   Downloading pytrec_eval_terrier-0.5.1-cp37-cp37m-manylinux2010_x86_64.whl (291 kB)
#      |████████████████████████████████| 291 kB 57.6 MB/s
# Collecting cwl-eval>=1.0.10
#   Downloading cwl-eval-1.0.10.tar.gz (31 kB)
# Collecting pyndeval>=0.0.2
#   Downloading pyndeval-0.0.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (59 kB)
#      |████████████████████████████████| 59 kB 5.7 MB/s
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from pyjnius~=1.3.0->python-terrier) (0.29.28)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from pyjnius~=1.3.0->python-terrier) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (2.10)
# Collecting cbor>=1.0.0
#   Downloading cbor-1.0.0.tar.gz (20 kB)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from chest->python-terrier) (1.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from deprecation->python-terrier) (21.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->python-terrier) (2.0.1)
# Collecting multiset<3.0,>=2.0
#   Downloading multiset-2.1.1-py2.py3-none-any.whl (8.8 kB)
# Collecting typish>=1.7.0
#   Downloading typish-1.9.3-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 1.0 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->deprecation->python-terrier) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->python-terrier) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->python-terrier) (2018.9)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn->python-terrier) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn->python-terrier) (3.1.0)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels->python-terrier) (0.5.2)
# Building wheels for collected packages: python-terrier, ir-measures, cwl-eval, cbor, warc3-wet-clueweb09, chest, wget
#   Building wheel for python-terrier (setup.py) ... done
#   Created wheel for python-terrier: filename=python_terrier-0.8.0-py3-none-any.whl size=103883 sha256=d8af9b957063c30ce676a2b1e5658e107f22c2bc4f600b8c3aabf72b84ff3726
#   Stored in directory: /root/.cache/pip/wheels/a8/ec/0c/fd9fcb409ad158d1f62534f9b1924b406f420f1a4170fb4132
#   Building wheel for ir-measures (setup.py) ... done
#   Created wheel for ir-measures: filename=ir_measures-0.2.3-py3-none-any.whl size=53217 sha256=0fa8da2460493d26e30971abc9123f3b152d8a25b636419849e0ac12da8348c2
#   Stored in directory: /root/.cache/pip/wheels/b2/06/1b/b8dc2d9a9802a9c30dd3a28d4199061297df0034d8ab9b808a
#   Building wheel for cwl-eval (setup.py) ... done
#   Created wheel for cwl-eval: filename=cwl_eval-1.0.10-py3-none-any.whl size=37797 sha256=f53bd697dd1ccb17463de4f2edd385cec540d9322eb620700f9f27b5d4a28bf8
#   Stored in directory: /root/.cache/pip/wheels/ff/e9/ff/d2b6d72d9feb0d0b1b11aacfaf5cd866717034615c2d194093
#   Building wheel for cbor (setup.py) ... done
#   Created wheel for cbor: filename=cbor-1.0.0-cp37-cp37m-linux_x86_64.whl size=51317 sha256=3ad388af95b07f8e729043f1fac2fc292653c3328a61d5c7861c9b62cf0e2934
#   Stored in directory: /root/.cache/pip/wheels/19/77/49/c9c2c8dc5848502e606e8579d0bbda18b850fb056a6c62239d
#   Building wheel for warc3-wet-clueweb09 (setup.py) ... done
#   Created wheel for warc3-wet-clueweb09: filename=warc3_wet_clueweb09-0.2.5-py3-none-any.whl size=18922 sha256=f032a9470883029d0bdd21ccf3607320629d5880721c2197e58b2a5a8df3f49d
#   Stored in directory: /root/.cache/pip/wheels/42/d4/3c/7c2b0c3d400ad744e4db69f2fde166655da2ed2198bfc02db6
#   Building wheel for chest (setup.py) ... done
#   Created wheel for chest: filename=chest-0.2.3-py3-none-any.whl size=7634 sha256=83b048a2ee2de8bd8069d41ada5e511d5ef37e3e58e1e221a999a02cbab16d9b
#   Stored in directory: /root/.cache/pip/wheels/fc/f5/b9/c436e11300809e6b40d46a5d2592fb0bff89e0712f2e878dc7
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=1f2072fd21f5a8886c43c425a76b6e1390fd3a90329e37bb96b4c464e324f434
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built python-terrier ir-measures cwl-eval cbor warc3-wet-clueweb09 chest wget
# Installing collected packages: cbor, zlib-state, warc3-wet-clueweb09, warc3-wet, typish, trec-car-tools, pyyaml, pytrec-eval-terrier, pyndeval, pyautocorpus, multiset, lz4, lxml, ijson, cwl-eval, wget, pyjnius, nptyping, matchpy, ir-measures, ir-datasets, deprecation, chest, python-terrier
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# Successfully installed cbor-1.0.0 chest-0.2.3 cwl-eval-1.0.10 deprecation-2.1.0 ijson-3.1.4 ir-datasets-0.5.0 ir-measures-0.2.3 lxml-4.8.0 lz4-4.0.0 matchpy-0.5.5 multiset-2.1.1 nptyping-1.4.4 pyautocorpus-0.1.8 pyjnius-1.3.0 pyndeval-0.0.2 python-terrier-0.8.0 pytrec-eval-terrier-0.5.1 pyyaml-6.0 trec-car-tools-2.6 typish-1.9.3 warc3-wet-0.2.3 warc3-wet-clueweb09-0.2.5 wget-3.2 zlib-state-0.1.5
# terrier-assemblies 5.6 jar-with-dependencies not found, downloading to /root/.pyterrier...
# Done
# terrier-python-helper 0.0.6 jar not found, downloading to /root/.pyterrier...
# Done
# terrier-prf -SNAPSHOT jar not found, downloading to /root/.pyterrier...
# Done
# PyTerrier 0.8.0 has loaded Terrier 5.6 (built by craigmacdonald on 2021-09-17 13:27)

# %% [markdown]
# ## Indexation d'une collection
#
# Il est possible d'indexer plusieurs formats de collection : format TREC, fichiers en texte brut ou en PDF, ou encore des Dataframe Pandas ([pour plus de détails](https://pyterrier.readthedocs.io/en/latest/terrier-indexing.html)).
#
# Un petit exemple à titre illustratif est foourni dans le code suivant :

# %%
import pandas as pd

# configuration de l'affichage
pd.set_option('display.max_colwidth', 150)

# le jeu de données au format DataFrame
docs_df = pd.DataFrame([
        ["d1", "this is the first document of many documents"],
        ["d2", "this is another document"],
        ["d3", "the topic of this document is unknown"]
    ], columns=["docno", "text"])

# création de l'index
indexer = pt.DFIndexer("./index_3docs", overwrite=True)         # Définition du format de données (DFIndexer())
index_ref = indexer.index(docs_df["text"], docs_df["docno"])    # Indexation des champs text et docno
# !ls -lh index_3docs/                                            # Affichage de l'index sauvegardé dans "./index_3docs/"
# Out:
# total 40K
# -rw-r--r-- 1 root root    3 Mar 10 13:05 data.direct.bf
# -rw-r--r-- 1 root root   51 Mar 10 13:05 data.document.fsarrayfile
# -rw-r--r-- 1 root root    4 Mar 10 13:05 data.inverted.bf
# -rw-r--r-- 1 root root  344 Mar 10 13:05 data.lexicon.fsomapfile
# -rw-r--r-- 1 root root  249 Mar 10 13:05 data.lexicon.fsomaphash
# -rw-r--r-- 1 root root   33 Mar 10 13:05 data.meta-0.fsomapfile
# -rw-r--r-- 1 root root   24 Mar 10 13:05 data.meta.idx
# -rw-r--r-- 1 root root   48 Mar 10 13:05 data.meta.zdata
# -rw-r--r-- 1 root root 4.1K Mar 10 13:05 data.properties

# %% [markdown]
# De nombreux fichiers sont créés : index direct, index inverse, méta-données de l'index et de la configuration de l'indexation, etc...
#
#
# Il est également possible de modifier la configuration de l'indexation : [voir ici](https://pyterrier.readthedocs.io/en/latest/terrier-indexing.html#indexing-configuration).
#
# Pour chager un index existant en local :

# %%
index = pt.IndexFactory.of(index_ref)

# %% [markdown]
# Il est aussi possible de voir les statistiques de l'index.
# pour connaître toutes les fonctions d'interrogation, se référencer à la [javadoc](http://terrier.org/docs/current/javadoc/org/terrier/structures/Index.html).

# %%
# statistiques de la collection
print(index.getCollectionStatistics().toString())
# Out:
# Number of documents: 3
# Number of terms: 4
# Number of postings: 6
# Number of fields: 0
# Number of tokens: 7
# Field names: []
# Positions:   false

# %%
# statistiques du vocabulaire.
# Nt : document frequency : nombre de documents contenant le terme
# TF : term frequency : nombre d'occurences du terme
# maxTF : nombre d'occurences maximal pour un document
for kv in index.getLexicon():
  print("%s (%s) -> %s (%s)" % (kv.getKey(), type(kv.getKey()), kv.getValue().toString(), type(kv.getValue()) ) )
# Out:
# document (<class 'str'>) -> term0 Nt=3 TF=4 maxTF=2 @{0 0 0} (<class 'jnius.reflect.org.terrier.structures.LexiconEntry'>)
# first (<class 'str'>) -> term1 Nt=1 TF=1 maxTF=1 @{0 0 7} (<class 'jnius.reflect.org.terrier.structures.LexiconEntry'>)
# topic (<class 'str'>) -> term2 Nt=1 TF=1 maxTF=1 @{0 1 1} (<class 'jnius.reflect.org.terrier.structures.LexiconEntry'>)
# unknown (<class 'str'>) -> term3 Nt=1 TF=1 maxTF=1 @{0 1 5} (<class 'jnius.reflect.org.terrier.structures.LexiconEntry'>)

# %%
# focus sur un terme particulier
index.getLexicon()["document"].toString()
# Out:
# 'term0 Nt=3 TF=4 maxTF=2 @{0 0 0}'

# %%
# récupère les statistiques de l'index inverse à partir d'un terme particulier
pointer = index.getLexicon()["document"]
for posting in index.getInvertedIndex().getPostings(pointer):
    print(posting.toString() + " doclen=%d" % posting.getDocumentLength())
# Out:
# ID(0) TF(2) doclen=3
# ID(1) TF(1) doclen=1
# ID(2) TF(1) doclen=3

# %% [markdown]
# De plus, PyTerrier met à disposition [une collection de jeux de données pré-traités](https://pyterrier.readthedocs.io/en/latest/datasets.html).
# Dans ce qui suit, nous allons nous concentrer sur le jeu de données CORD19 qui recense des articles liés à la crise sanitaire Covid-19. Il est

# %%
import os

cord19 = pt.datasets.get_dataset('irds:cord19/trec-covid')
pt_index_path = './terrier_cord19'

if not os.path.exists(pt_index_path + "/data.properties"):
  # création de l'index. Utilisation de l'itérateur pour parcourir la collection
  indexer = pt.index.IterDictIndexer(pt_index_path)

  # on donne à l'index la fonction pour parcourir l'index avec l'itérateur  get_corpus_iter() 
  # On spécifie les champs à indexer et les meta-données à sauvegarder
  index_ref = indexer.index(cord19.get_corpus_iter(), 
                            fields=('abstract',), 
                            meta=('docno',))

else:
  # dans le cas où l'index existe déjà
  index_ref = pt.IndexRef.of(pt_index_path + "/data.properties")
index = pt.IndexFactory.of(index_ref)
# Out:
# [INFO] [starting] building docstore
# [INFO] If you have a local copy of https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv, you can symlink it here to avoid downloading it again: /root/.ir_datasets/downloads/80d664e496b8b7e50a39c6f6bb92e0ef
# [INFO] [starting] https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv
# docs_iter:   0%|                                    | 0/192509 [00:00<?, ?doc/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 0.0%| 0.00/269M [00:00<?, ?B/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 0.0%| 24.6k/269M [00:00<21:45, 206kB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 0.0%| 57.3k/269M [00:00<19:42, 228kB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 0.0%| 90.1k/269M [00:00<19:08, 234kB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 0.1%| 229k/269M [00:00<10:07, 443kB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 0.2%| 492k/269M [00:00<05:55, 755kB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 0.4%| 999k/269M [00:00<03:30, 1.27MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 0.6%| 1.69M/269M [00:00<02:25, 1.84MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 1.3%| 3.39M/269M [00:01<01:22, 3.23MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 2.1%| 5.62M/269M [00:01<00:55, 4.75MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 2.9%| 7.85M/269M [00:01<00:43, 5.96MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 3.7%| 10.1M/269M [00:01<00:37, 6.94MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 4.6%| 12.3M/269M [00:01<00:33, 7.77MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 5.4%| 14.5M/269M [00:01<00:30, 8.46MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 6.2%| 16.8M/269M [00:01<00:27, 9.05MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 7.1%| 19.0M/269M [00:01<00:26, 9.57MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 7.9%| 21.2M/269M [00:02<00:24, 10.0MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 8.7%| 23.4M/269M [00:02<00:23, 10.4MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 9.5%| 25.7M/269M [00:02<00:22, 10.8MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 10.4%| 27.9M/269M [00:02<00:21, 11.1MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 11.2%| 30.1M/269M [00:02<00:21, 11.4MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 12.0%| 32.4M/269M [00:02<00:20, 11.6MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 12.8%| 34.6M/269M [00:02<00:19, 11.9MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 13.7%| 36.8M/269M [00:03<00:19, 12.1MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 14.5%| 39.0M/269M [00:03<00:18, 12.3MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 15.3%| 41.3M/269M [00:03<00:18, 12.5MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 16.2%| 43.5M/269M [00:03<00:17, 12.6MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 17.0%| 45.7M/269M [00:03<00:17, 12.8MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 17.8%| 48.0M/269M [00:03<00:17, 12.9MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 18.6%| 50.2M/269M [00:03<00:16, 13.1MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 19.5%| 52.4M/269M [00:03<00:16, 13.2MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 20.3%| 54.6M/269M [00:04<00:16, 13.3MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 21.1%| 56.9M/269M [00:04<00:15, 13.4MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 22.0%| 59.2M/269M [00:04<00:15, 13.5MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 22.9%| 61.6M/269M [00:04<00:15, 13.7MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 23.7%| 63.9M/269M [00:04<00:14, 13.8MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 24.6%| 66.2M/269M [00:04<00:14, 13.9MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 25.5%| 68.6M/269M [00:04<00:14, 14.0MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 26.3%| 70.9M/269M [00:05<00:14, 14.1MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 27.2%| 73.3M/269M [00:05<00:13, 14.2MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 28.1%| 75.6M/269M [00:05<00:13, 14.3MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 29.0%| 78.0M/269M [00:05<00:13, 14.3MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 29.8%| 80.3M/269M [00:05<00:13, 14.4MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 30.7%| 82.6M/269M [00:05<00:12, 14.5MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 31.6%| 85.0M/269M [00:05<00:12, 14.6MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 32.4%| 87.3M/269M [00:05<00:12, 14.6MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 33.3%| 89.7M/269M [00:06<00:12, 14.7MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 34.2%| 92.0M/269M [00:06<00:12, 14.8MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 35.0%| 94.4M/269M [00:06<00:11, 14.8MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 35.9%| 96.7M/269M [00:06<00:11, 14.9MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 36.8%| 99.0M/269M [00:06<00:11, 14.9MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 37.7%| 101M/269M [00:06<00:11, 15.0MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 38.5%| 104M/269M [00:06<00:11, 15.0MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 39.4%| 106M/269M [00:07<00:10, 15.1MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 40.3%| 108M/269M [00:07<00:10, 15.1MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 41.1%| 111M/269M [00:07<00:10, 15.2MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 42.0%| 113M/269M [00:07<00:10, 15.2MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 42.9%| 115M/269M [00:07<00:10, 15.3MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 43.8%| 118M/269M [00:07<00:09, 15.3MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 44.6%| 120M/269M [00:07<00:09, 15.3MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 45.5%| 122M/269M [00:07<00:09, 15.4MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 46.4%| 125M/269M [00:08<00:09, 15.4MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 47.2%| 127M/269M [00:08<00:09, 15.5MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 48.1%| 130M/269M [00:08<00:09, 15.5MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 49.0%| 132M/269M [00:08<00:08, 15.6MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 50.0%| 134M/269M [00:08<00:08, 15.6MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 50.9%| 137M/269M [00:08<00:08, 15.6MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 51.8%| 139M/269M [00:08<00:08, 15.7MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 52.7%| 142M/269M [00:09<00:08, 15.7MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 53.6%| 144M/269M [00:09<00:07, 15.8MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 54.6%| 147M/269M [00:09<00:07, 15.8MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 55.5%| 149M/269M [00:09<00:07, 15.9MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 56.4%| 152M/269M [00:09<00:07, 15.9MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 57.3%| 154M/269M [00:09<00:07, 15.9MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 58.2%| 157M/269M [00:09<00:07, 16.0MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 59.1%| 159M/269M [00:09<00:06, 16.0MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 60.1%| 162M/269M [00:10<00:06, 16.0MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 61.0%| 164M/269M [00:10<00:06, 16.1MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 61.9%| 167M/269M [00:10<00:06, 16.1MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 62.8%| 169M/269M [00:10<00:06, 16.1MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 63.7%| 172M/269M [00:10<00:06, 16.2MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 64.7%| 174M/269M [00:10<00:05, 16.2MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 65.6%| 177M/269M [00:10<00:05, 16.2MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 66.5%| 179M/269M [00:11<00:05, 16.2MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 67.4%| 182M/269M [00:11<00:05, 16.3MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 68.3%| 184M/269M [00:11<00:05, 16.3MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 69.3%| 186M/269M [00:11<00:05, 16.3MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 70.2%| 189M/269M [00:11<00:04, 16.4MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 71.1%| 191M/269M [00:11<00:04, 16.4MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 72.0%| 194M/269M [00:11<00:04, 16.4MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 72.9%| 196M/269M [00:11<00:04, 16.4MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 73.9%| 199M/269M [00:12<00:04, 16.5MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 74.8%| 201M/269M [00:12<00:04, 16.5MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 75.7%| 204M/269M [00:12<00:03, 16.5MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 76.6%| 206M/269M [00:12<00:03, 16.5MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 77.5%| 209M/269M [00:12<00:03, 16.6MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 78.4%| 211M/269M [00:12<00:03, 16.6MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 79.4%| 214M/269M [00:12<00:03, 16.6MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 80.3%| 216M/269M [00:13<00:03, 16.6MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 81.3%| 219M/269M [00:13<00:03, 16.7MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 82.3%| 222M/269M [00:13<00:02, 16.7MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 83.3%| 224M/269M [00:13<00:02, 16.7MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 84.4%| 227M/269M [00:13<00:02, 16.8MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 85.4%| 230M/269M [00:13<00:02, 16.8MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 86.5%| 233M/269M [00:13<00:02, 16.9MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 87.5%| 236M/269M [00:13<00:01, 16.9MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 88.6%| 238M/269M [00:14<00:01, 16.9MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 89.6%| 241M/269M [00:14<00:01, 17.0MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 90.7%| 244M/269M [00:14<00:01, 17.0MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 91.7%| 247M/269M [00:14<00:01, 17.1MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 92.8%| 250M/269M [00:14<00:01, 17.1MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 93.8%| 253M/269M [00:14<00:00, 17.1MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 94.9%| 255M/269M [00:14<00:00, 17.2MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 95.9%| 258M/269M [00:15<00:00, 17.2MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 97.0%| 261M/269M [00:15<00:00, 17.2MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 98.0%| 264M/269M [00:15<00:00, 17.3MB/s]
#
# [INFO] [finished] https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: [00:15] [269MB] [17.3MB/s]
# docs_iter:   0%|                                    | 0/192509 [00:16<?, ?doc/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: [00:15] [269MB] [17.3MB/s]
# docs_iter: 100%|█████████████████████| 192509/192509 [00:26<00:00, 7144.56doc/s]
# [INFO] [finished] docs_iter: [00:26] [192509doc] [7144.24doc/s]
# [INFO] [finished] building docstore [26.96s]
# cord19/trec-covid documents:   0%|          | 0/192509 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: specifying meta and meta_lengths in IterDictIndexer.index() is deprecated, use constructor instead
# 13:10:00.023 [ForkJoinPool-1-worker-3] WARN org.terrier.structures.indexing.Indexer - Adding an empty document to the index (6iu1dtyl) - further warnings are suppressed
# 13:11:25.115 [ForkJoinPool-1-worker-3] WARN org.terrier.structures.indexing.Indexer - Indexed 54937 empty documents
# 13:11:25.212 [ForkJoinPool-1-worker-3] ERROR org.terrier.structures.indexing.Indexer - Could not finish MetaIndexBuilder:
# java.io.IOException: Key 8lqzfj2e is not unique: 37597,11755
# For MetaIndex, to suppress, set metaindex.compressed.reverse.allow.duplicates=true
# 	at org.terrier.structures.collections.FSOrderedMapFile$MultiFSOMapWriter.mergeTwo(FSOrderedMapFile.java:1374)
# 	at org.terrier.structures.collections.FSOrderedMapFile$MultiFSOMapWriter.close(FSOrderedMapFile.java:1308)
# 	at org.terrier.structures.indexing.BaseMetaIndexBuilder.close(BaseMetaIndexBuilder.java:321)
# 	at org.terrier.structures.indexing.classical.BasicIndexer.createDirectIndex(BasicIndexer.java:346)
# 	at org.terrier.structures.indexing.Indexer.index(Indexer.java:369)
# 	at org.terrier.python.ParallelIndexer$1.apply(ParallelIndexer.java:63)
# 	at org.terrier.python.ParallelIndexer$1.apply(ParallelIndexer.java:52)
# 	at java.base/java.util.stream.ReferencePipeline$3$1.accept(ReferencePipeline.java:195)
# 	at java.base/java.util.Spliterators$ArraySpliterator.forEachRemaining(Spliterators.java:948)
# 	at java.base/java.util.stream.AbstractPipeline.copyInto(AbstractPipeline.java:484)
# 	at java.base/java.util.stream.AbstractPipeline.wrapAndCopyInto(AbstractPipeline.java:474)
# 	at java.base/java.util.stream.ReduceOps$ReduceTask.doLeaf(ReduceOps.java:952)
# 	at java.base/java.util.stream.ReduceOps$ReduceTask.doLeaf(ReduceOps.java:926)
# 	at java.base/java.util.stream.AbstractTask.compute(AbstractTask.java:327)
# 	at java.base/java.util.concurrent.CountedCompleter.exec(CountedCompleter.java:746)
# 	at java.base/java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:290)
# 	at java.base/java.util.concurrent.ForkJoinTask.doInvoke(ForkJoinTask.java:408)
# 	at java.base/java.util.concurrent.ForkJoinTask.invoke(ForkJoinTask.java:736)
# 	at java.base/java.util.stream.ReduceOps$ReduceOp.evaluateParallel(ReduceOps.java:919)
# 	at java.base/java.util.stream.AbstractPipeline.evaluate(AbstractPipeline.java:233)
# 	at java.base/java.util.stream.ReferencePipeline.reduce(ReferencePipeline.java:558)
# 	at org.terrier.python.ParallelIndexer$3.call(ParallelIndexer.java:133)
# 	at org.terrier.python.ParallelIndexer$3.call(ParallelIndexer.java:130)
# 	at java.base/java.util.concurrent.ForkJoinTask$AdaptedCallable.exec(ForkJoinTask.java:1448)
# 	at java.base/java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:290)
# 	at java.base/java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1020)
# 	at java.base/java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1656)
# 	at java.base/java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1594)
# 	at java.base/java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:183)

# %% [markdown]
# **Exercice 1**
#
# Afficher les statistiques de l'index Cord19 et analyser statistiques du terme "tv" (pas trop fréquent pour question d'affichage).

# %%
index.getLexicon()["tv"].toString()
# Nt --> nombre de document dans lequel le terme apparait
# TF --> nombre d'apparition du terme dans le corpus
# maxTF --> nombre max d'apparition d'un terme dans un document
# Out:
# 'term18759 Nt=70 TF=180 maxTF=2147483647 @{0 18614194 0} TFf=180'

# %%
pointer = index.getLexicon()["tv"]
for posting in index.getInvertedIndex().getPostings(pointer):
    print(posting.toString() + " doclen=%d" % posting.getDocumentLength())
# Out:
# (2777,3,F[3]) doclen=219
# (10054,1,F[1]) doclen=258
# (11115,3,F[3]) doclen=228
# (11396,1,F[1]) doclen=173
# (11998,1,F[1]) doclen=70
# (15443,2,F[2]) doclen=65
# (22159,1,F[1]) doclen=74
# (24922,1,F[1]) doclen=51
# (29671,2,F[2]) doclen=165
# (32156,1,F[1]) doclen=259
# (38532,7,F[7]) doclen=166
# (42346,5,F[5]) doclen=236
# (43113,10,F[10]) doclen=193
# (43829,1,F[1]) doclen=203
# (49420,2,F[2]) doclen=151
# (50340,4,F[4]) doclen=193
# (51298,4,F[4]) doclen=146
# (51965,1,F[1]) doclen=64
# (55321,2,F[2]) doclen=248
# (56159,1,F[1]) doclen=227
# (56638,4,F[4]) doclen=149
# (60575,1,F[1]) doclen=135
# (61226,4,F[4]) doclen=245
# (61831,1,F[1]) doclen=188
# (62509,1,F[1]) doclen=229
# (64784,6,F[6]) doclen=159
# (69551,5,F[5]) doclen=100
# (70746,1,F[1]) doclen=226
# (71655,1,F[1]) doclen=163
# (71784,1,F[1]) doclen=182
# (72685,1,F[1]) doclen=317
# (77313,1,F[1]) doclen=193
# (77512,1,F[1]) doclen=123
# (81426,1,F[1]) doclen=150
# (85336,9,F[9]) doclen=165
# (86932,3,F[3]) doclen=161
# (87660,11,F[11]) doclen=245
# (92317,4,F[4]) doclen=358
# (92318,4,F[4]) doclen=358
# (93468,1,F[1]) doclen=211
# (93469,1,F[1]) doclen=211
# (93470,1,F[1]) doclen=211
# (94464,1,F[1]) doclen=143
# (100127,2,F[2]) doclen=105
# (104277,1,F[1]) doclen=161
# (107572,1,F[1]) doclen=148
# (109543,1,F[1]) doclen=146
# (112876,1,F[1]) doclen=59
# (115225,1,F[1]) doclen=64
# (117310,1,F[1]) doclen=123
# (124580,1,F[1]) doclen=135
# (124581,1,F[1]) doclen=135
# (133016,4,F[4]) doclen=358
# (137261,1,F[1]) doclen=87
# (138078,7,F[7]) doclen=101
# (146385,1,F[1]) doclen=204
# (149236,1,F[1]) doclen=95
# (149369,4,F[4]) doclen=66
# (150489,1,F[1]) doclen=143
# (151398,2,F[2]) doclen=153
# (154850,1,F[1]) doclen=110
# (159172,1,F[1]) doclen=60
# (161158,1,F[1]) doclen=114
# (163798,21,F[21]) doclen=335
# (170377,2,F[2]) doclen=167
# (181062,1,F[1]) doclen=137
# (185736,1,F[1]) doclen=260
# (188360,1,F[1]) doclen=161
# (188498,1,F[1]) doclen=123
# (188949,2,F[2]) doclen=141

# %% [markdown]
# ## Recherche de documents à partir de l'index
#
# Pour effectuer une recherche dans l'index, il faut utiliser la fonction batchRetrieve qui prend en paramètre l'index et le modèle de pondération (tf, tf-idf, etc...). La liste des modèles supportés est disponible [ici](http://terrier.org/docs/current/javadoc/org/terrier/matching/models/package-summary.html).

# %%
br = pt.BatchRetrieve(index, wmodel="Tf")
br.search("chemical reactions")
# Out:
#     qid   docid     docno  rank  score               query
# 0     1   12409  ij3ncdb6     0   21.0  chemical reactions
# 1     1   24432  094bk0t0     1   13.0  chemical reactions
# 2     1   11268  qroxmo85     2   12.0  chemical reactions
# 3     1  120041  pb00yr0r     3   12.0  chemical reactions
# 4     1  147193  ei4rb8fr     4   12.0  chemical reactions
# ..   ..     ...       ...   ...    ...                 ...
# 995   1   96252  8clnrlec   995    2.0  chemical reactions
# 996   1   96758  rvw94nsg   996    2.0  chemical reactions
# 997   1   97138  lrx94c81   997    2.0  chemical reactions
# 998   1   98181  w3160mgp   998    2.0  chemical reactions
# 999   1   98642  dhoyiqtx   999    2.0  chemical reactions
#
# [1000 rows x 6 columns]

# %% [markdown]
# On récupère alors un DataFrame dont les colonnes sont les suivantes :
# *   qid : identifiant de la requête. Par défaut, il s'agit de "1", puisqu'il s'agit de notre première et unique requête.
# *   docid : l'identifiant interne de Terrier pour chaque document
# *   docno : l'identifiant unique externe (chaîne de caractères) pour chaque document
# *   score : score des documents selon le modèle choisi (ici : fréquence totale des tf des termes de la requête dans chaque document)
# *   rank : rang du document dénotant l'ordre décroissant par score.
# *   query : la requête d'entrée

# %%
# autre exemple de modèle : TF-IDF
tfidf = pt.BatchRetrieve(index, wmodel="TF_IDF")
tfidf.search("chemical reactions")
# Out:
#     qid   docid     docno  rank      score               query
# 0     1   18717  iavwkdpr     0  11.035982  chemical reactions
# 1     1  171636  v3blnh02     1  10.329726  chemical reactions
# 2     1  147193  ei4rb8fr     2  10.317138  chemical reactions
# 3     1  121217  msdycum2     3   9.653734  chemical reactions
# 4     1  170863  sj8i9ss2     4   9.500211  chemical reactions
# ..   ..     ...       ...   ...        ...                 ...
# 995   1    2428  38aabxh1   995   3.790183  chemical reactions
# 996   1   14752  u709r8ss   996   3.790183  chemical reactions
# 997   1   20074  wxi1xsbo   997   3.790183  chemical reactions
# 998   1  117156  ts3obwts   998   3.790183  chemical reactions
# 999   1  149517  6i3x49p8   999   3.790183  chemical reactions
#
# [1000 rows x 6 columns]

# %% [markdown]
# On peut aussi fournir plusieurs requêtes grâce à un dataFrame. Pour interroger l'index, on applique la fonction transform() au BatchRetriever (br).
# pour plus de détails, voir [les propriétés des transformations](https://pyterrier.readthedocs.io/en/latest/transformer.html) ainsi que les [opérations possibles](https://pyterrier.readthedocs.io/en/latest/operators.html).

# %%
import pandas as pd
queries = pd.DataFrame([["q1", "document"], ["q2", "first document"]], columns=["qid", "query"])
br.transform(queries)       # ou aussi : br(queries)
# Out:
#      qid   docid     docno  rank  score           query
# 0     q1   14569  mm7gxjf1     0   12.0        document
# 1     q1  137615  duxm9u8v     1   12.0        document
# 2     q1   18789  x3o3a45b     2   10.0        document
# 3     q1  189505  hxp258y8     3   10.0        document
# 4     q1   37445  q5wglpoj     4    9.0        document
# ...   ..     ...       ...   ...    ...             ...
# 1995  q2  137347  xye8pgzt   995    3.0  first document
# 1996  q2  137487  k0y0fz7k   996    3.0  first document
# 1997  q2  138448  ut3ayexx   997    3.0  first document
# 1998  q2  138807  fulh7trp   998    3.0  first document
# 1999  q2  139327  2a84u4tm   999    3.0  first document
#
# [2000 rows x 6 columns]

# %% [markdown]
# **Exercice 2**
#
# Ordonnancer les documents pour 3 requêtes : "covid disease", "hospital" et "home".
# La fonction d'ordonnacement devra être de la forme suivante :
#
#
# ```
# 0.4 * score_Bm25 + 0.6 * score_Dirichlet
# ```

# %%
queries = pd.DataFrame([["q1", "covid disease"], ["q2", "hospital"], ["q3", "home"]], columns=["qid", "query"])

dlm = pt.BatchRetrieve(index, wmodel="DirichletLM")
bm25 = pt.BatchRetrieve(index, wmodel="BM25")

df1 = dlm.transform(queries)
df2 = bm25.transform(queries)

df1.sort_values(by=['docid'], inplace=True)
df2.sort_values(by=['docid'], inplace=True)

df1.drop(columns=["docno", "rank", "query"], inplace=True)
df2.drop(columns=["docno", "rank", "query"], inplace=True)

res = pd.merge(df1, df2, how ='outer', on =["docid", "qid"])
res["score"] = 0.6 * res["score_x"] + 0.4 * res["score_y"]
res.drop(columns=["score_x", "score_y"], inplace=True)
res.sort_values(by=['score'], inplace=True, ascending=False)

print("ID du meilleur doc:", res["docid"][0])
print(res)
# Out:
# ID du meilleur doc: 152
#      qid   docid     score
# 896   q3   73694  7.256685
# 308   q3   37219  7.175818
# 807   q3   71618  7.128688
# 304   q3   36315  6.907965
# 2442  q3  160321  6.791849
# ...   ..     ...       ...
# 4186  q2  192290       NaN
# 4187  q3  192310       NaN
# 4188  q3  192360       NaN
# 4189  q1  192486       NaN
# 4190  q1  192500       NaN
#
# [4191 rows x 3 columns]

# %%
pipeline = dlm >> bm25
print(pipeline.transform(queries))

linear = 0.4*bm25 + 0.6*dlm
print(linear.transform(queries))
# Out:
#      qid   docid     docno  rank     score          query
# 0     q1   43498  9d8go2sl     0  6.148625  covid disease
# 1     q1  106017  a0w3n30z     1  6.148625  covid disease
# 2     q1  106018  smyp9fyo     2  6.148625  covid disease
# 3     q1  106019  vtfn9y5p     3  6.148625  covid disease
# 4     q1  158611  30ff3xg2     4  6.124425  covid disease
# ...   ..     ...       ...   ...       ...            ...
# 2995  q3   62102  n5qaaqxn   995  4.065851           home
# 2996  q3   58015  x7or04u6   996  3.808793           home
# 2997  q3   74632  i8litb66   997  3.770778           home
# 2998  q3  163315  i1gdsiw6   998  3.676422           home
# 2999  q3  160913  o0mhzx3g   999  3.212039           home
#
# [3000 rows x 6 columns]
#      qid     docid     docno     score          query  rank
# 0     q1   43498.0  9d8go2sl  3.067285  covid disease     1
# 1     q1  106017.0  a0w3n30z  3.067285  covid disease     2
# 2     q1  106018.0  smyp9fyo  3.067285  covid disease     3
# 3     q1  106019.0  vtfn9y5p  3.067285  covid disease     4
# 4     q1  158611.0  30ff3xg2  3.370553  covid disease     0
# ...   ..       ...       ...       ...            ...   ...
# 4216  q3       NaN  h5iew8oo  1.011830            NaN  1222
# 4217  q3       NaN  x7or04u6  0.989607            NaN  1223
# 4218  q3       NaN  i8litb66  0.987562            NaN  1224
# 4219  q3       NaN  i1gdsiw6  0.982324            NaN  1225
# 4220  q3       NaN  o0mhzx3g  0.952669            NaN  1226
#
# [4221 rows x 6 columns]

# %%
# TF_IDF = pt.BatchRetrieve(index, wmodel="TF_IDF")
# DPH = pt.BatchRetrieve(index, wmodel="DPH")
# PL2 = pt.BatchRetrieve(index, wmodel="PL2")
# DLM = pt.BatchRetrieve(index, wmodel="DirichletLM")
# BM25 = pt.BatchRetrieve(index, wmodel="BM25")

# queries = pd.DataFrame([["q1", "covid disease"], ["q2", "hospital"], ["q3", "home"]], columns=["qid", "query"])
  
# pt.Experiment([TF_IDF, DPH, PL2, DLM, BM25], queries, ?????, eval_metrics=["map"])

# %% [markdown]
# **Excercice 3**
#
# Créez un ordonnanceur qui effectue les opérations suivantes :
# * obtient les 10 documents les mieux notés par fréquence de terme (wmodel="Tf")
# * obtenir les 10 documents les mieux notés par TF.IDF (wmodel="TF_IDF")
# * ré-ordonne uniquement les documents trouvés dans les DEUX paramètres de recherche précédents en utilisant BM25.
#
# Combien de documents sont récupérés par ce pipeline complet pour la requête "chemical"?
#
# Vérification : le document avec le docno "37771" devrait avoir un score de 12.426309 $ pour la requête "chemical".

# %%
querie = "chemical"
tf = pt.BatchRetrieve(index, wmodel="Tf",num_results=10)
tf_idf = pt.BatchRetrieve(index, wmodel="TF_IDF",num_results=10)
bm25 = pt.BatchRetrieve(index, wmodel="BM25")

pipeline = (tf & tf_idf) >> bm25
result = pipeline.search(querie)
result
# Out:
#   qid   docid     docno  rank      score     query
# 0   1   37771  jn5qi1jb     0  12.426309  chemical
# 1   1  134305  0smev8vt     1  12.292890  chemical
# 2   1  142104  77c9ohxj     2  12.226076  chemical
# 3   1   56631  sps45fj5     3  11.642770  chemical
# 4   1    2524  ifebw24e     4  11.439890  chemical

# %% [markdown]
# ## Reformulation de requêtes
#
# Il est également possible de mettre en place des pipelines de [reformulation de requêtes](https://pyterrier.readthedocs.io/en/latest/rewrite.html).

# %%
bo1 = pt.rewrite.Bo1QueryExpansion(index)
dph = pt.BatchRetrieve(index, wmodel="DPH")
pipeline = dph >> bo1 >> dph
pipeline.search("chemical reactions")
# Out:
#     qid   docid     docno  rank      score             query_0  \
# 0     1  147193  ei4rb8fr     0  20.728032  chemical reactions
# 1     1  171636  v3blnh02     1  20.684654  chemical reactions
# 2     1   18717  iavwkdpr     2  11.160010  chemical reactions
# 3     1   20409  1g9kmpdi     3  10.702739  chemical reactions
# 4     1  170863  sj8i9ss2     4  10.347593  chemical reactions
# ..   ..     ...       ...   ...        ...                 ...
# 995   1  114233  2cxb65j1   995   3.942073  chemical reactions
# 996   1  183279  8emqwp2o   996   3.942073  chemical reactions
# 997   1   88197  f7g1zacc   997   3.941175  chemical reactions
# 998   1  178340  zsp5v8hv   998   3.938286  chemical reactions
# 999   1   60135  jx9yrpl6   999   3.938271  chemical reactions
#
#                                                                                                                                                      query
# 0    applypipeline:off chemic^1.457741865 reaction^1.302919515 hazard^0.306805986 reactiv^0.283917121 explos^0.245621780 exotherm^0.236822495 bioproces...
# 1    applypipeline:off chemic^1.457741865 reaction^1.302919515 hazard^0.306805986 reactiv^0.283917121 explos^0.245621780 exotherm^0.236822495 bioproces...
# 2    applypipeline:off chemic^1.457741865 reaction^1.302919515 hazard^0.306805986 reactiv^0.283917121 explos^0.245621780 exotherm^0.236822495 bioproces...
# 3    applypipeline:off chemic^1.457741865 reaction^1.302919515 hazard^0.306805986 reactiv^0.283917121 explos^0.245621780 exotherm^0.236822495 bioproces...
# 4    applypipeline:off chemic^1.457741865 reaction^1.302919515 hazard^0.306805986 reactiv^0.283917121 explos^0.245621780 exotherm^0.236822495 bioproces...
# ..                                                                                                                                                     ...
# 995  applypipeline:off chemic^1.457741865 reaction^1.302919515 hazard^0.306805986 reactiv^0.283917121 explos^0.245621780 exotherm^0.236822495 bioproces...
# 996  applypipeline:off chemic^1.457741865 reaction^1.302919515 hazard^0.306805986 reactiv^0.283917121 explos^0.245621780 exotherm^0.236822495 bioproces...
# 997  applypipeline:off chemic^1.457741865 reaction^1.302919515 hazard^0.306805986 reactiv^0.283917121 explos^0.245621780 exotherm^0.236822495 bioproces...
# 998  applypipeline:off chemic^1.457741865 reaction^1.302919515 hazard^0.306805986 reactiv^0.283917121 explos^0.245621780 exotherm^0.236822495 bioproces...
# 999  applypipeline:off chemic^1.457741865 reaction^1.302919515 hazard^0.306805986 reactiv^0.283917121 explos^0.245621780 exotherm^0.236822495 bioproces...
#
# [1000 rows x 7 columns]

# %% [markdown]
# L'autre solution est de l'intégrer directement dans la fonction d'ordonnancement. Mais la requête reformulée n'est pas visible et la solution précédente fait prendre conscience de la pipeline faite par le système de RI (ranking >> reformulation >> ranking quand on utilise des modèles basés sur la relevance feedback. ou reformulation >> ranking sinon). Plus d'exemples [ici](https://pyterrier.readthedocs.io/en/latest/rewrite.html).

# %%
# modèle DPH avant reformulation de requête
pipelineQE = pt.BatchRetrieve(index, wmodel="DPH", controls={"qemodel" : "Bo1", "qe" : "off"})
pipelineQE.search("chemical reactions")
# Out:
#     qid   docid     docno  rank      score               query
# 0     1  171636  v3blnh02     0  11.898228  chemical reactions
# 1     1  147193  ei4rb8fr     1  11.889920  chemical reactions
# 2     1   18717  iavwkdpr     2  11.688030  chemical reactions
# 3     1  170863  sj8i9ss2     3  10.143884  chemical reactions
# 4     1  121217  msdycum2     4   9.860973  chemical reactions
# ..   ..     ...       ...   ...        ...                 ...
# 995   1  154582  q4neat3x   995   4.070840  chemical reactions
# 996   1  171895  yjbcvf3o   996   4.070840  chemical reactions
# 997   1   14781  0it25j3k   997   4.067507  chemical reactions
# 998   1   70003  a1nc5k51   998   4.067507  chemical reactions
# 999   1   73765  sjod3q3j   999   4.067507  chemical reactions
#
# [1000 rows x 6 columns]

# %%
# modèle DPH après reformulation de requête
pipelineQE = pt.BatchRetrieve(index, wmodel="DPH", controls={"qemodel" : "Bo1", "qe" : "on"})
pipelineQE.search("chemical reactions")
# Out:
#     qid   docid     docno  rank      score               query
# 0     1  147193  ei4rb8fr     0  20.728032  chemical reactions
# 1     1  171636  v3blnh02     1  20.684654  chemical reactions
# 2     1   18717  iavwkdpr     2  11.160010  chemical reactions
# 3     1   20409  1g9kmpdi     3  10.702739  chemical reactions
# 4     1  170863  sj8i9ss2     4  10.347593  chemical reactions
# ..   ..     ...       ...   ...        ...                 ...
# 995   1  114233  2cxb65j1   995   3.942073  chemical reactions
# 996   1  183279  8emqwp2o   996   3.942073  chemical reactions
# 997   1   88197  f7g1zacc   997   3.941175  chemical reactions
# 998   1  178340  zsp5v8hv   998   3.938286  chemical reactions
# 999   1   60135  jx9yrpl6   999   3.938271  chemical reactions
#
# [1000 rows x 6 columns]

# %% [markdown]
# ### Evaluation d'un système de recherche d'information
#
# Pour évaluer un système de RI, il est nécessaire d'avoir un jeu de données constitué de requêtes et de jugements de pertinence.

# %%
# exemple de 5 requêtes pour cord19
cord19.get_topics(variant='title').head(5)
# Out:
# [INFO] [starting] https://ir.nist.gov/covidSubmit/data/topics-rnd5.xml
# [INFO] [finished] https://ir.nist.gov/covidSubmit/data/topics-rnd5.xml: [00:00] [18.7kB] [14.6MB/s]
# /usr/local/lib/python3.7/dist-packages/pyterrier/datasets.py:433: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df.drop(df.columns.difference(['qid','query']), 1, inplace=True)
#   qid                                    query
# 0   1                       coronavirus origin
# 1   2  coronavirus response to weather changes
# 2   3                     coronavirus immunity
# 3   4   how do people die from the coronavirus
# 4   5                animal models of covid 19

# %%
# exemple de jugements de pertinence pour les 5 premières requêtes
cord19.get_qrels().head(5)
# Out:
# [INFO] [starting] https://ir.nist.gov/covidSubmit/data/qrels-covid_d5_j0.5-5.txt
# [INFO] [finished] https://ir.nist.gov/covidSubmit/data/qrels-covid_d5_j0.5-5.txt: [00:07] [1.14MB] [145kB/s]
#   qid     docno  label iteration
# 0   1  005b2j4b      2       4.5
# 1   1  00fmeepz      1         4
# 2   1  010vptx3      2       0.5
# 3   1  0194oljo      1       2.5
# 4   1  021q9884      1         4

# %% [markdown]
# **Exercice 4**
#
# A partir des requêtes et des jugements de pertinence du jeu de données CORD19, Ecrire le code qui permet d'afficher les résultats de la première requête de Cord19. L'affichage fusionnera les colonnes retournées par le BatchRetriever et les colonnes des qrels (merge sur qid et docno pour rajouter label et iteration au tableau).

# %%
bo1 = pt.rewrite.Bo1QueryExpansion(index)
dph = pt.BatchRetrieve(index, wmodel="DPH")
pipeline = dph >> bo1 >> dph
res = pipeline.search(cord19.get_topics(variant='title')["query"][0])
merged = pd.merge(res, cord19.get_qrels(), how ='inner', on =["docno", "qid"])

merged
# Out:
# /usr/local/lib/python3.7/dist-packages/pyterrier/datasets.py:433: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df.drop(df.columns.difference(['qid','query']), 1, inplace=True)
#     qid   docid     docno  rank      score             query_0  \
# 0     1   82224  8ccl9aui     0  11.661505  coronavirus origin
# 1     1   84953  ax6v6ham     1  11.430387  coronavirus origin
# 2     1   45549  8l411r1w     2   9.242285  coronavirus origin
# 3     1  175892  zy8qjaai     3   8.763194  coronavirus origin
# 4     1  166596  d2knbzhl     4   8.614349  coronavirus origin
# ..   ..     ...       ...   ...        ...                 ...
# 464   1  146110  4ywt0yqn   965   5.090643  coronavirus origin
# 465   1   75817  55loucvc   972   5.084005  coronavirus origin
# 466   1  186503  erntrh3p   992   5.052921  coronavirus origin
# 467   1   57809  e6h1qvdk   996   5.044950  coronavirus origin
# 468   1  121648  3ll2tlzr   997   5.044950  coronavirus origin
#
#                                                                                                                                                      query  \
# 0    applypipeline:off coronaviru^1.190927068 origin^1.341147614 phylogenet^0.249566089 analys^0.242429428 sar^0.200830689 spike^0.142504108 nucleocaps...
# 1    applypipeline:off coronaviru^1.190927068 origin^1.341147614 phylogenet^0.249566089 analys^0.242429428 sar^0.200830689 spike^0.142504108 nucleocaps...
# 2    applypipeline:off coronaviru^1.190927068 origin^1.341147614 phylogenet^0.249566089 analys^0.242429428 sar^0.200830689 spike^0.142504108 nucleocaps...
# 3    applypipeline:off coronaviru^1.190927068 origin^1.341147614 phylogenet^0.249566089 analys^0.242429428 sar^0.200830689 spike^0.142504108 nucleocaps...
# 4    applypipeline:off coronaviru^1.190927068 origin^1.341147614 phylogenet^0.249566089 analys^0.242429428 sar^0.200830689 spike^0.142504108 nucleocaps...
# ..                                                                                                                                                     ...
# 464  applypipeline:off coronaviru^1.190927068 origin^1.341147614 phylogenet^0.249566089 analys^0.242429428 sar^0.200830689 spike^0.142504108 nucleocaps...
# 465  applypipeline:off coronaviru^1.190927068 origin^1.341147614 phylogenet^0.249566089 analys^0.242429428 sar^0.200830689 spike^0.142504108 nucleocaps...
# 466  applypipeline:off coronaviru^1.190927068 origin^1.341147614 phylogenet^0.249566089 analys^0.242429428 sar^0.200830689 spike^0.142504108 nucleocaps...
# 467  applypipeline:off coronaviru^1.190927068 origin^1.341147614 phylogenet^0.249566089 analys^0.242429428 sar^0.200830689 spike^0.142504108 nucleocaps...
# 468  applypipeline:off coronaviru^1.190927068 origin^1.341147614 phylogenet^0.249566089 analys^0.242429428 sar^0.200830689 spike^0.142504108 nucleocaps...
#
#      label iteration
# 0        2         1
# 1        1       3.5
# 2        0         1
# 3        1         1
# 4        0         1
# ..     ...       ...
# 464      0         4
# 465      2         5
# 466      0         3
# 467      1         5
# 468      1         5
#
# [469 rows x 9 columns]

# %% [markdown]
# Il existe cependant une fonction qui permet de calculer l'efficacité de ces ordonnancements au travers des métriques d'évaluation (map, précision, rappel, ndcg, ...)

# %%
pt.Experiment(
    [tfidf],
    cord19.get_topics(variant='title'),
    cord19.get_qrels(),
    eval_metrics=["map", "ndcg"])
# Out:
# /usr/local/lib/python3.7/dist-packages/pyterrier/datasets.py:433: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df.drop(df.columns.difference(['qid','query']), 1, inplace=True)
#          name       map      ndcg
# 0  BR(TF_IDF)  0.180002  0.370767

# %% [markdown]
# **Exercice 5**
#
# Réaliser une expérience comparant l'expansion de requêtes avec le modèle Bo1 et basé sur la KL-divergence; L'expérience est réalisée sur TREC CORD19 avec le modèle de référence BM25. Vous devrez construire des pipelines appropriées (plus de détails sur [l'expansion](https://pyterrier.readthedocs.io/en/latest/rewrite.html) et les [expérimentations](https://pyterrier.readthedocs.io/en/latest/experiments.html)).
#
# Quelles approches entraînent des augmentations significatives de NDCG et MAP ou autres métriques ?

# %%
bo1 = pt.rewrite.Bo1QueryExpansion(index)
kl = pt.rewrite.KLQueryExpansion(index)
bm25 = pt.BatchRetrieve(index, wmodel="BM25")

pipeline1 = bm25 >> bo1 >> bm25
pipeline2 = bm25 >> kl >> bm25

pipeline3 = tfidf >> bo1 >> tfidf
pipeline4 = tfidf >> kl >> tfidf

# %%
pt.Experiment(
    [pipeline1],
    cord19.get_topics(variant='title'),
    cord19.get_qrels(),
    eval_metrics=["map", "ndcg"])
# Out:
# /usr/local/lib/python3.7/dist-packages/pyterrier/datasets.py:433: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df.drop(df.columns.difference(['qid','query']), 1, inplace=True)
#                                                                                                    name  \
# 0  Compose(Compose(BR(BM25), <pyterrier.rewrite.Bo1QueryExpansion object at 0x7f436e34a910>), BR(BM25))
#
#         map      ndcg
# 0  0.190398  0.388397

# %%
pt.Experiment(
    [pipeline2],
    cord19.get_topics(variant='title'),
    cord19.get_qrels(),
    eval_metrics=["map", "ndcg"])
# Out:
# /usr/local/lib/python3.7/dist-packages/pyterrier/datasets.py:433: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df.drop(df.columns.difference(['qid','query']), 1, inplace=True)
#                                                                                                   name  \
# 0  Compose(Compose(BR(BM25), <pyterrier.rewrite.KLQueryExpansion object at 0x7f436e34ac50>), BR(BM25))
#
#         map      ndcg
# 0  0.193292  0.391679

# %%
pt.Experiment(
    [pipeline3],
    cord19.get_topics(variant='title'),
    cord19.get_qrels(),
    eval_metrics=["map", "ndcg"])
# Out:
# /usr/local/lib/python3.7/dist-packages/pyterrier/datasets.py:433: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df.drop(df.columns.difference(['qid','query']), 1, inplace=True)
#                                                                                                        name  \
# 0  Compose(Compose(BR(TF_IDF), <pyterrier.rewrite.Bo1QueryExpansion object at 0x7f436e34a910>), BR(TF_IDF))
#
#         map      ndcg
# 0  0.191959  0.387534

# %%
pt.Experiment(
    [pipeline4],
    cord19.get_topics(variant='title'),
    cord19.get_qrels(),
    eval_metrics=["map", "ndcg"])
# Out:
# /usr/local/lib/python3.7/dist-packages/pyterrier/datasets.py:433: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df.drop(df.columns.difference(['qid','query']), 1, inplace=True)
#                                                                                                       name  \
# 0  Compose(Compose(BR(TF_IDF), <pyterrier.rewrite.KLQueryExpansion object at 0x7f436e34ac50>), BR(TF_IDF))
#
#        map      ndcg
# 0  0.19524  0.391334
